# %%
import os
import pandas as pd
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')
from IPython.display import clear_output

# %%
default_jupytext_formats = "ipynb,py:percent"

# %%
folder=input("paste your reading folder:")
search_text='WarrantyByItem'

# %%
file_list=[]
for (root, dirs, file) in os.walk(folder):
    for f in file:
        if ('.xlsx') in f:
            if search_text in f:
                file_list.append(f)
file_list
# Out:
# ['WarrantyByItem-BrakePartsIncLLC-V0ASARU--01-01-2025-01-31-2025-ALL-ALL-20250201085206.xlsx',
#  'WarrantyByItem-CardoneIndustriesInc-V0ASARU--12-01-2024-12-31-2024-ALL-ALL-20250104072315.xlsx',
#  'WarrantyByItem-CarterFuelSystemsLLC-V0ASARU--12-01-2024-12-31-2024-ALL-ALL-20250104072253.xlsx',
#  'WarrantyByItem-ChampionLaboratoriesInc-V0ASARU--12-01-2024-12-31-2024-ALL-ALL-20250104072240.xlsx',
#  'WarrantyByItem-FramGroupOperationsLLC-V0ASARU--12-01-2024-12-31-2024-ALL-ALL-20250104072231.xlsx',
#  'WarrantyByItem-HopkinsManufacturingCorporation-V0ASARU--12-01-2024-12-31-2024-ALL-ALL-20250104072217.xlsx',
#  'WarrantyByItem-HorizonGlobalAmericasInc-V0ASARU--12-01-2024-12-31-2024-ALL-ALL-20250104072200.xlsx',
#  'WarrantyByItem-InternationalBrakeIndustriesInc-V0ASARU--12-01-2024-12-31-2024-ALL-ALL-20250104072145.xlsx',
#  'WarrantyByItem-TricoProductsCorp-V0ASARU--12-01-2024-12-31-2024-ALL-ALL-20250104072128.xlsx']

# %%
file_link=[]

for i in range(len(file_list)):
     for r,d,f in os.walk(folder):
          for files in f:
               if files == file_list[i]:
                    file_link.append(os.path.join(r,files))

# %%
file_link
# Out:
# ['C:\\Users\\vikram.vadhirajan\\Downloads\\WarrantyByItem-BrakePartsIncLLC-V0ASARU--01-01-2025-01-31-2025-ALL-ALL-20250201085206.xlsx',
#  'C:\\Users\\vikram.vadhirajan\\Downloads\\WarrantyByItem-CardoneIndustriesInc-V0ASARU--12-01-2024-12-31-2024-ALL-ALL-20250104072315.xlsx',
#  'C:\\Users\\vikram.vadhirajan\\Downloads\\WarrantyByItem-CarterFuelSystemsLLC-V0ASARU--12-01-2024-12-31-2024-ALL-ALL-20250104072253.xlsx',
#  'C:\\Users\\vikram.vadhirajan\\Downloads\\WarrantyByItem-ChampionLaboratoriesInc-V0ASARU--12-01-2024-12-31-2024-ALL-ALL-20250104072240.xlsx',
#  'C:\\Users\\vikram.vadhirajan\\Downloads\\WarrantyByItem-FramGroupOperationsLLC-V0ASARU--12-01-2024-12-31-2024-ALL-ALL-20250104072231.xlsx',
#  'C:\\Users\\vikram.vadhirajan\\Downloads\\WarrantyByItem-HopkinsManufacturingCorporation-V0ASARU--12-01-2024-12-31-2024-ALL-ALL-20250104072217.xlsx',
#  'C:\\Users\\vikram.vadhirajan\\Downloads\\WarrantyByItem-HorizonGlobalAmericasInc-V0ASARU--12-01-2024-12-31-2024-ALL-ALL-20250104072200.xlsx',
#  'C:\\Users\\vikram.vadhirajan\\Downloads\\WarrantyByItem-InternationalBrakeIndustriesInc-V0ASARU--12-01-2024-12-31-2024-ALL-ALL-20250104072145.xlsx',
#  'C:\\Users\\vikram.vadhirajan\\Downloads\\WarrantyByItem-TricoProductsCorp-V0ASARU--12-01-2024-12-31-2024-ALL-ALL-20250104072128.xlsx']

# %%
df=pd.DataFrame()
for file in file_link:
    df1=pd.read_excel(file)
    Brand=file.split("-")[1]
    df1["SourceName"]=file.split("-")[1]
    df=pd.concat([df,df1])
    print(f"{Brand} is appended to the data")
    print(f"total Line so far is {len(df)}")
    clear_output(wait=True)
# Out:
# TricoProductsCorp is appended to the data
# total Line so far is 94289

# %%
month=input("Please enter month in this format (mmm-yy) eg: for January 2025 it is Jan-25: ")
df['Extracted On']=month

# %%
Ofolder=input("paste your output folder here :")
filename=f"Warranty_report_Orielly_{month}"
df.to_csv(Ofolder+f'\\{filename}.csv')

# %%
print("The file Warranty_report_Orielly.csv is created ")
input("Press any key to close")
