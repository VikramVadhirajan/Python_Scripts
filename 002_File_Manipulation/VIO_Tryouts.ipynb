# %%
#!pip install ipywidgets

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\Vikram.Vadhirajan\OneDrive - Trico\FBG\01_DRA\00_Projects\99_Automation_Projects\98_Misc_Codes\VIOdata2023.xlsx",sheet_name='VIOdata2023')

# %%
df
# Out:
#        Region  Version VehicleTypeGroupName VehicleTypeName   MakeName  \
# 0          US   202301           Light Duty             Car      Honda
# 1          US   202301           Light Duty             Car     Toyota
# 2          US   202301           Light Duty             Car     Toyota
# 3          US   202301           Light Duty             Car      Honda
# 4          US   202301           Light Duty             Car  Chevrolet
# ...       ...      ...                  ...             ...        ...
# 243094     US   202301           Light Duty           Truck       Jeep
# 243095     US   202301           Light Duty             Car    Ferrari
# 243096     US   202301           Light Duty             Car      Lexus
# 243097     US   202301           Light Duty             Car      Lexus
# 243098     US   202301           Light Duty             Car    Bentley
#
#                ModelName  YearID  BaseVehicleID SubModelName  RegionID  ...  \
# ...

# %%
@interact
def filtermake(VehCount= (1,max(df.VehCount),100)):
    return df[df['VehCount'] > VehCount]
# Out:
# interactive(children=(IntSlider(value=100901, description='VehCount', max=201978, min=1, step=100), Output()),…
