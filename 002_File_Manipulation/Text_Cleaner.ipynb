# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd
import datetime
import warnings


# Ignore all warnings (not recommended in general)
warnings.filterwarnings("ignore")

# %%
f=open(r"C:\Users\vikram.vadhirajan\OneDrive - Trico\FBG\99_Downloads\NISSAN.txt",'r')
Linebraker='marketplace-product row '

# %%
content=f.read()
List=content.split(Linebraker)
print(len(List))
# Out:
# 55

# %%
List[1]
# Out:
# '">\n\t<div class="product-image-col col-md-2">\n\t\t\t\t<a href="/parts/nissan-fan-assembly-214813lm0a?c=bD0xJm49U2VhcmNoIFJlc3VsdHM%3D" class="product-image-link" data-routing="ignore">\n\t\t\t<img src="//s3.amazonaws.com/rp-part-images/assets/a86a76d850c093083a39ba77137a1c80.webp" alt="214813LM0A - : Fan Assembly for Nissan: NV200 Image" title="214813LM0A - : Fan Assembly for Nissan: NV200">\n\t\t</a>\n\t\t\t</div> <!-- .col-xs-2 -->\n\t<div class="product-details-col col-md-10 row">\n\t\t<div class="col-xs-12 col-md-8">\n\t\t\t<strong class="product-title">\n\t<a class="title-link" href="/parts/nissan-fan-assembly-214813lm0a?c=bD0xJm49U2VhcmNoIFJlc3VsdHM%3D" title="Fan Assembly" aria-label="View details for Fan Assembly">Fan Assembly</a>\n</strong>\n\t\t\t\t\t\t\t\t\t<div class="product-prices">\n\t\t\t\t\t\t\t\t<div class="list-price-only">\n\t\t\t\t\t<span class="list-price-label"> MSRP </span>\n\t\t\t\t\t$462.32\n\t\t\t\t</div> <!-- .list-price -->\n\t\t\t\t\t\t\t\t\t\t\t</div
# ...

# %%
prefix="https://parts.nissanusa.com"

# %%
List[1].split('title="')[2].split('"')[0]
# Out:
# 'Fan Assembly'

# %%
List[1].split('title="')[1].split(" : ")[1].split(":")[0]
# Out:
# 'Fan Assembly for Nissan'

# %%
cols =['Sl.No'] #,'Review_Mentions'
df = pd.DataFrame(columns=cols)
count=0

# %%
for i in range (1,len(List)):
    df.loc[count,'Sl.No']=i
    df.loc[count,'Name']=List[i].split('title="')[2].split('"')[0]
    df.loc[count,'PartNumber']=(List[i].split('title="')[1].split(" ")[0])
    df.loc[count,'MSRP']=(float(List[i].split(' MSRP </span>')[1].split('</div>')[0].strip().replace("$","").replace(",","")))
    df.loc[count,'Fitment']=(List[i].split('fitment-model ">')[1].split('</li>')[0])
    try:
        df.loc[count,'Replaces']=(List[i].split('Replaces:</strong>\n\t')[1].split('</div>')[0])
    except:
        df.loc[count,'Replaces']=('null')
    df.loc[count,"Link"]=prefix+List[i].split('href="')[1].split('?')[0]
    count=count+1

# %%
df
# Out:
#    Sl.No                           Name  PartNumber     MSRP      Fitment  \
# 0      1                   Fan Assembly  214813LM0A   462.32        NV200
# 1      2                   Fan Assembly  214815AA1A   379.93       Murano
# 2      3                   Fan Assembly  214815SA0B   340.68         LEAF
# 3      4                   Fan Assembly  214816CB0A   524.43       Altima
# 4      5                   Fan Assembly  214816GP1A  1067.77            Z
# 5      6                   Fan Assembly  214816RR0B   501.10        Rogue
# 6      7                   Fan Assembly  214819BU0A   546.35     Frontier
# 7      8                   Fan Assembly  21481JG70A   832.33      Rogue,
# 8      9                   Fan Assembly  21481JK60B   839.77         370Z
# 9     10                   Fan Assembly  21481ZX50A   383.70       Altima
# 10    11                   Fan Assembly  272202Y910   221.67       Maxima
# 11    12                   Fan Assembly  214813JA2E   580.94   Pathfinder
# ...
