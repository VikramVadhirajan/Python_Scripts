# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\Vikram.Vadhirajan\OneDrive - Trico\Documents - Product Support India Romania\Catalog Migration\Project Unify Files\calipers\Comparison\cpcx_bdbl_calipers_attr_matches_updated.xlsx")

# %%
df
# Out:
#       subject_part_number reference_part_number  total_attributes_compared  \
# 0                18-B5636             FRC13329C                       18.0
# 1                19-B7554             FRC13119N                       18.0
# 2               18-B5477A             FRC13106N                       18.0
# 3                18-B5642             FRC13199C                       18.0
# 4                19-B7555             FRC13120C                       18.0
# ...                   ...                   ...                        ...
# 38287            18-B5559             FRC12889C                       18.0
# 38288                 NaN                   NaN                        NaN
# 38289                 NaN                   NaN                        NaN
# 38290                 NaN                   NaN                        NaN
# 38291                 NaN                   NaN                        NaN
#
# ...

# %%
df.columns
# Out:
# Index(['subject_part_number', 'reference_part_number',
#        'total_attributes_compared', 'overall_match', 'Total TRUE Count',
#        'Total FALSE Count', 'Total NO DATA Count',
#        'CardoneReman_Bleeder Screw Included_Bleeder Screw Included',
#        'Raybestos_Bleeder Screw Included_Bleeder Screw Included',
#        'Bleeder Screw Included_match_Bleeder Screw Included',
#        'CardoneReman_Bleeder Thread Size_Bleeder Screw Thread',
#        'Raybestos_Bleeder Screw Thread_Bleeder Thread Size',
#        'Bleeder Screw Thread_match_Bleeder Thread Size',
#        'CardoneReman_Caliper Finish_Caliper Bracket Surface Finish',
#        'Raybestos_Caliper Bracket Surface Finish_Caliper Finish',
#        'Caliper Bracket Surface Finish_match_Caliper Finish',
#        'CardoneReman_Caliper Finish_Surface Finish',
#        'Raybestos_Surface Finish_Caliper Finish',
#        'Surface Finish_match_Caliper Finish',
#        'CardoneReman_Caliper Type_Caliper Type',
# ...

# %%
for i in df.columns[7:]:
    if "match" not in i:
        print("----------------------------------------------------------------------------------------------------------------------")
        print(df[i].value_counts())
# Out:
# ----------------------------------------------------------------------------------------------------------------------
# Yes    38082
# Name: CardoneReman_Bleeder Screw Included_Bleeder Screw Included, dtype: int64
# ----------------------------------------------------------------------------------------------------------------------
# Yes    475
# Name: Raybestos_Bleeder Screw Included_Bleeder Screw Included, dtype: int64
# ----------------------------------------------------------------------------------------------------------------------
# M10x1.0     17728
# M7x1.0       5917
# 3/8x24       5085
# M10x1.5      5001
# M10x1.25     1756
# M8x1.25      1303
# M8x1.0        635
# 7/16x24       374
# M8x1.5        108
# 7/16x20        50
# 1/4x28         38
# 5/16x24        15
# Name: CardoneReman_Bleeder Thread Size_Bleeder Screw Thread, dtype: int64
# ----------------------------------------------------------------------------------------------------------------------
# ...

# %%
repllist={'''M10x1.0''':'''M10x1''',
'''M7x1.0''':'''M7x1''',
'''3/8x24''':'''M10 x 1.5''',
'''M10x1.5''':'''M10x1.5''',
'''M10x1.25''':'''M10x1.25''',
'''M8x1.25''':'''M8x1.25''',
'''M8x1.0''':'''M8x1''',
'''7/16x24''':'''M10x1''',
'''M8x1.5''':'''M8x1.5''',
'''7/16x20''':'''M12 x 1.75''',
'''1/4x28''':'''M6 x 1''',
'''5/16x24''':'''M8 x 1.25'''}

print(df['''CardoneReman_Bleeder Thread Size_Bleeder Screw Thread'''].value_counts())

df['CardoneReman_Bleeder Thread Size_Bleeder Screw Thread'] = df['CardoneReman_Bleeder Thread Size_Bleeder Screw Thread'].replace(repllist, regex=True)


df['''CardoneReman_Bleeder Thread Size_Bleeder Screw Thread'''].value_counts()
# Out:
# M10x1.0     17728
# M7x1.0       5917
# 3/8x24       5085
# M10x1.5      5001
# M10x1.25     1756
# M8x1.25      1303
# M8x1.0        635
# 7/16x24       374
# M8x1.5        108
# 7/16x20        50
# 1/4x28         38
# 5/16x24        15
# Name: CardoneReman_Bleeder Thread Size_Bleeder Screw Thread, dtype: int64
# M10x1         18102
# M7x1           5917
# M10 x 1.5      5085
# M10x1.5        5001
# M10x1.25       1756
# M8x1.25        1303
# M8x1            635
# M8x1.5          108
# M12 x 1.75       50
# M6 x 1           38
# M8 x 1.25        15
# Name: CardoneReman_Bleeder Thread Size_Bleeder Screw Thread, dtype: int64

# %%
repllist={'''M10x1''':'''M10x1''',
'''M7x1''':'''M7x1''',
'''3/8"-24''':'''M10 x 1.5''',
'''M10x1.5''':'''M10x1.5''',
'''M10x1.25''':'''M10x1.25''',
'''M8x1.25''':'''M8x1.25''',
'''M8x1''':'''M8x1''',
'''7/16"-24''':'''M10x1''',
'''M10x1.0''':'''M10x1''',
'''M10X1.00''':'''M10X1''',
'''1/4"-28''':'''M6 x 1''',
'''M7X1.00''':'''M7X1''',
'''5/16"-24''':'''M8 x 1.25''',
'''7/16"-20''':'''M12 x 1.75''',
'''M10x1.50''':'''M10x1.5''',
'''M7x1.00''':'''M7x1'''}


print( df['''Raybestos_Bleeder Screw Thread_Bleeder Thread Size'''].value_counts())
df['Raybestos_Bleeder Screw Thread_Bleeder Thread Size'] = df['Raybestos_Bleeder Screw Thread_Bleeder Thread Size'].replace(repllist, regex=True)


df['''Raybestos_Bleeder Screw Thread_Bleeder Thread Size'''].value_counts()
# Out:
# M10x1       15538
# M7x1         5772
# 3/8"-24      5160
# M10x1.5      4629
# M10x1.25     1578
# M8x1.25      1011
# M8x1          502
# 7/16"-24      244
# M10x1.0       223
# M10X1.00      120
# 1/4"-28        30
# M7X1.00        26
# 5/16"-24       17
# 7/16"-20       16
# M10x1.50        6
# M7x1.00         2
# Name: Raybestos_Bleeder Screw Thread_Bleeder Thread Size, dtype: int64
# M10x1         16005
# M7x1           5774
# M10 x 1.5      5160
# M10x1.5        4635
# M10x1.25       1578
# M8x1.25        1011
# M8x1            502
# M10X1           120
# M6 x 1           30
# M7X1             26
# M8 x 1.25        17
# M12 x 1.75       16
# Name: Raybestos_Bleeder Screw Thread_Bleeder Thread Size, dtype: int64

# %%
repllist={12:12,
14:14,
16:16,
10:10,
11.98408:12,
10.00366:10,
11.98:12,
15.9957:16,
7.99785:8,
13.98989:14,
12.23798:12.23,
13.99:14}

print(df['''Raybestos_Caliper Bracket Mounting Hole Size_Mounting Hole Diameter'''].value_counts())

df['Raybestos_Caliper Bracket Mounting Hole Size_Mounting Hole Diameter'] = df['Raybestos_Caliper Bracket Mounting Hole Size_Mounting Hole Diameter'].replace(repllist, regex=True)


df['''Raybestos_Caliper Bracket Mounting Hole Size_Mounting Hole Diameter'''].value_counts()
# Out:
# 12.00000    4144
# 14.00000    3514
# 16.00000    1836
# 10.00000    1334
# 11.98408      88
# 10.00366      20
# 11.98000      18
# 15.99570      12
# 7.99785        8
# 13.98989       7
# 12.23798       4
# 13.99000       2
# Name: Raybestos_Caliper Bracket Mounting Hole Size_Mounting Hole Diameter, dtype: int64
# 12.00    4250
# 14.00    3523
# 16.00    1848
# 10.00    1354
# 8.00        8
# 12.23       4
# Name: Raybestos_Caliper Bracket Mounting Hole Size_Mounting Hole Diameter, dtype: int64

# %%
repllist={12:12,
14:14,
16:16,
10:10,
11.98408:12,
10.00366:10,
11.98:12,
15.9957:16,
7.99785:8,
13.98989:14,
12.23798:12.23,
13.99:14}


print(df['''Raybestos_Caliper Bracket Mounting Hole Size_Mounting Hole Thread Diameter'''].value_counts())

df['Raybestos_Caliper Bracket Mounting Hole Size_Mounting Hole Thread Diameter'] = df['Raybestos_Caliper Bracket Mounting Hole Size_Mounting Hole Thread Diameter'].replace(repllist, regex=True)


df['''Raybestos_Caliper Bracket Mounting Hole Size_Mounting Hole Thread Diameter'''].value_counts()
# Out:
# 12.00000    4144
# 14.00000    3514
# 16.00000    1836
# 10.00000    1334
# 11.98408      88
# 10.00366      20
# 11.98000      18
# 15.99570      12
# 7.99785        8
# 13.98989       7
# 12.23798       4
# 13.99000       2
# Name: Raybestos_Caliper Bracket Mounting Hole Size_Mounting Hole Thread Diameter, dtype: int64
# 12.00    4250
# 14.00    3523
# 16.00    1848
# 10.00    1354
# 8.00        8
# 12.23       4
# Name: Raybestos_Caliper Bracket Mounting Hole Size_Mounting Hole Thread Diameter, dtype: int64

# %%
repllist={"M12x1.25":"M12x1.25",
"M10x1.25":"M10x1.25",
"M14 X 2.0":"M14x2",
"M14 X 1.5":"M14x1.5",
"M12x1.75":"M12x1.75",
"M12x1.5":"M12x1.5",
"M16x2.0":"M16x2",
"M16x1.5":"M16x1.5",
"M10x1.5":"M10x1.5",
"M12X1.25":"M12x1.25",
"M14x1.25":"M14x1.25",
"M14 X1.25":"M14x1.25",
"M18x2.5":"M18x2.5",
"M12X1.75":"M12x1.75",
"M16 X 2.0":"M16x2",
"M15 X 1.5":"M15x1.5",
"M14X1.5":"M14x1.5",
"M10X1.25":"M10x1.25",
"M12 X 1.25":"M12x1.25",
"M14 X 1.50":"M14x1.5",
"M12 X 1.5":"M12x1.5",
"M14X2.0":"M14x2",
"M12 X 1.5":"M12x1.5",
"M14x1.5":"M14x1.5",
"M12X1.50":"M12x1.5",
"M20x2.5":"M20x2.5",
"M10x1.0":"M10x1",
"M18x1.5":"M18x1.5",
"M12X 1.75":"M12x1.75",
"M10 X 1.5":"M10x1.5",
"M9x1.25":"M9x1.25",
"M10x1.25/M14x1.25":"M10x1.25/M14x1.25",
"M14X1.25":"M14x1.25",
"M10x1.75":"M10x1.75",
"M12x1.25/M9x1.0":"M12x1.25/M9x1",
"M20x1.5":"M20x1.5",
"M14X1. 5":"M14x1.5",
"M14 x 1.5":"M14x1.5",
"M14 X 1.75":"M14x1.75",
"9/16 X 12":"M14x2",
"M12x2.0":"M12x2"}




print(df['''CardoneReman_Mounting Hole Thread size_Caliper Bracket Mounting Hole Thread Pitch'''].value_counts())

df['CardoneReman_Mounting Hole Thread size_Caliper Bracket Mounting Hole Thread Pitch'] = df['CardoneReman_Mounting Hole Thread size_Caliper Bracket Mounting Hole Thread Pitch'].replace(repllist, regex=True)


df['''CardoneReman_Mounting Hole Thread size_Caliper Bracket Mounting Hole Thread Pitch'''].value_counts()
# Out:
# M12x1.25             5336
# M10x1.25             2477
# M14x2                2272
# M14x1.5              1980
# M12x1.75             1618
# M12x1.5               718
# M16x2                 672
# M16x1.5               516
# M10x1.5               383
# M14x1.25              291
# M18x2.5                84
# M15x1.5                48
# M14x1.50               37
# M12x1.50               26
# M20x2.5                24
# M18x1.5                24
# M10x1                  24
# M9x1.25                16
# M10x1.25/M14x1.25      12
# M10x1.75               10
# M12x1.25/M9x1           8
# M20x1.5                 6
# M14X1 .5                5
# M14x1.75                4
# M12x2                   2
# Name: CardoneReman_Mounting Hole Thread size_Caliper Bracket Mounting Hole Thread Pitch, dtype: int64
# M12x1.25             5336
# M10x1.25             2477
# M14x2                2272
# M14x1.5              1980
# M12x1.75             1618
# M12x1.5               718
# M16x2                 672
# ...
