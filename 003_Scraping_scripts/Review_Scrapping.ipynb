"https://www.amazon.com/dp/B08JHGXN7D",
"https://www.amazon.com/dp/B0BPTG1G8X",
"https://www.amazon.com/dp/B07W58L66R",
"https://www.amazon.com/dp/B00HESVC8U",
"https://www.amazon.com/dp/B0BRN5TC68",
"https://www.amazon.com/dp/B0BX6CLG2C",
"https://www.amazon.com/dp/B08L462B87",
"https://www.amazon.com/dp/B08L44X6NZ",
"https://www.amazon.com/dp/B082FNTCJT",
"https://www.amazon.com/dp/B082FMVD3P",
"https://www.amazon.com/dp/B07BS74TPF",
"https://www.amazon.com/dp/B071WP4CHS",
"https://www.amazon.com/dp/B0849XSSH3",
"https://www.amazon.com/dp/B08594NBKB",
"https://www.amazon.com/dp/B09V1T8WNW",
"https://www.amazon.com/dp/B07GNMVHJT",
"https://www.amazon.com/dp/B071WP5VP9",
"https://www.amazon.com/dp/B07V39MYDG",
"https://www.amazon.com/dp/B07V56QYZ8",
"https://www.amazon.com/dp/B08L447MY5",
"https://www.amazon.com/dp/B071JR7DXV",
"https://www.amazon.com/dp/B0BJ3CWQHW",
"https://www.amazon.com/dp/B085HX5B6F",
"https://www.amazon.com/dp/B07XF5FNSS",
"https://www.amazon.com/dp/B071WNMQGH",
"https://www.amazon.com/dp/B07GNK7HSM",
"https://www.amazon.com/dp/B08L455C1J",
"https://www.amazon.com/dp/B09V1TR191",
"https://www.amazon.com/dp/B07213TGBJ",
"https://www.amazon.com/dp/B07213G8HQ",
"https://www.amazon.com/dp/B0BS1VL8R8",
"https://www.amazon.com/dp/B0BXFGCKLZ",
"https://www.amazon.com/dp/B07J5SY3V1",
"https://www.amazon.com/dp/B09V1VQYSN",
"https://www.amazon.com/dp/B09V1QS8PR",
"https://www.amazon.com/dp/B01KZV319U",
"https://www.amazon.com/dp/B01M8INHN4",
"https://www.amazon.com/dp/B016VADTCS",
"https://www.amazon.com/dp/B01KZV3398"
]

# %%
len(links)
# Out:
# 294

# %%
cols =['Sl.No'] 
df = pd.DataFrame(columns=cols)
df
count=0

# %%
timestamp=[]
timediff=[]
from IPython.display import clear_output 
import numpy as np
def timeremaining(balanceitem,i):
    timestamp.insert(i,datetime.datetime.now())
    if i>=1:
        diff=timestamp[i]-timestamp[i-1]
        timediff.insert(i,diff.total_seconds())		
        remainingtime=np.median(timediff)*balanceitem
        millis=int(remainingtime)		
        #print(millis)
        seconds=(millis)%60
        seconds = int(seconds)
        minutes=(millis/(60))%60
        minutes = int((minutes)) #math.floor
        hours=(millis/(60*60))%24
        hours=int(hours)
        print(f'Item Scraped: {i+1} \nItems Remining: {balanceitem-1} and \nTime Remaining: {hours}:{minutes}:{seconds}')
        clear_output(wait=True)

# %%
driver=webdriver.Chrome()
wait=WebDriverWait(driver, 5)
driver.maximize_window()

# %%
driver.get(links[1])

# %%
location = driver.find_element(By.ID, 'nav-global-location-popover-link')

location.click()
sleep(1)
pin = driver.find_element(By.ID, 'GLUXZipUpdateInput')
pinnumber='94203'
pin.send_keys(pinnumber)

apply=driver.find_element(By.CSS_SELECTOR, 'span.a-button-inner[data-action="GLUXPostalUpdateAction"]')
apply.click()

# %%
driver.find_element(By.CSS_SELECTOR,'[class="a-row a-spacing-medium"]').click()
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20956\2405185597.py in <module>
# ----> 1 driver.find_element(By.CSS_SELECTOR,'[class="a-row a-spacing-medium"]').click()
#
# c:\Users\Vikram.Vadhirajan\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      91     def click(self) -> None:
#      92         """Clicks the element."""
# ---> 93         self._execute(Command.CLICK_ELEMENT)
#      94
#      95     def submit(self):
#
# c:\Users\Vikram.Vadhirajan\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     392             params = {}
#     393         params["id"] = self._id
# --> 394         return self._parent.execute(command, params)
#     395
#     396     def find_element(self, by=By.ID, value=None) -> WebElement:
#
# ...

# %%
rcount=0
rlist=[]
for i in range(5):
    reviewlist=driver.find_elements(By.CSS_SELECTOR, '[data-hook="review-body"]')
    for element in reviewlist:
        review_text = element.text
        #print(review_text)
        rlist.append(review_text)
        rcount=rcount+1
    sleep(1)
    try:
        nextpage=wait.until(EC.presence_of_element_located((By.XPATH, '//li[@class="a-last"]/a')))
        nextpage.click()
        i=i+1
    except:
        pass

# %%
rlist
# Out:
# ["broke in 4 years. Now I'm in the process of trying to figure out how to submit a warranty claim. I've been working on this for 4 hours and still am unable to submit. I sent an email to warrantyquestions@amazon.com but it came back as undeliverable. Customer service is a complete disaster.",
#  'According to the listing, this was made to fit 2019 to 2023 Chevrolet Silverado with the 5.8 bed, proceeded to do the install, and very easy the rails fit perfectly. However, when I attempted to install the cover, it was 1 inch too short width wise. Not sure why it could be possible that it was packaged with the wrong cover, but everything else seemed to be a correct kind of a bummer because I was really trying to have it installed due to me having to use my truck to carry around some stuff I wasn’t trying to get wet ended up using a tarp. I’m gonna contact him to see if it was just a mistake.',
# ...

# %%
for j in range(len(links)):
    driver.get(links[j])
    sleep(1)
    df.loc[count,'Sl.No']=count+1
    df.loc[count,"Link"]=links[j]
    wait.until(EC.presence_of_element_located((By.TAG_NAME,'body'))).send_keys(Keys.END)
    image_element = wait.until(EC.presence_of_element_located((By.XPATH,'//div[@id="imgTagWrapperId"]/img')))

    # Get the source URL of the image
    image_source_url = image_element.get_attribute("src")
    df.loc[count,"Image"]=image_source_url
    #Select the reviews

    review_page=driver.find_element(By.CSS_SELECTOR,'[data-hook="see-all-reviews-link-foot"]')
    sleep(1)
    review_page.click()
    sleep(1)

    dropdown_button = driver.find_element(By.ID, 'a-autoid-5-announce')
    dropdown_button.click()

    option_text = 'Critical reviews'
    option_locator = (By.XPATH, f"//a[contains(text(), '{option_text}')]")
    cr=wait.until(EC.element_to_be_clickable(option_locator))
    cr.click()
    rcount=0
    rlist=[]
    for i in range(5):
        reviewlist=driver.find_elements(By.CSS_SELECTOR, '[data-hook="review-body"]')
        for element in reviewlist:
            review_text = element.text
            #print(review_text)
            rlist.append(review_text)
            rcount=rcount+1
        sleep(1)
        try:
            nextpage=wait.until(EC.presence_of_element_located((By.XPATH, '//li[@class="a-last"]/a')))
            nextpage.click()
            i=i+1
        except:
            pass
        sleep(1)
    print(rlist)
    print(len(rlist))
    df.at[count,'Reviews']=rlist
    count=count+1    
    balanceitem=len(links)-j
    timeremaining(balanceitem,j)
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20956\2986013120.py in <module>
#      14     review_page=driver.find_element(By.CSS_SELECTOR,'[data-hook="see-all-reviews-link-foot"]')
#      15     sleep(1)
# ---> 16     review_page.click()
#      17     sleep(1)
#      18
#
# c:\Users\Vikram.Vadhirajan\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      91     def click(self) -> None:
#      92         """Clicks the element."""
# ---> 93         self._execute(Command.CLICK_ELEMENT)
#      94
#      95     def submit(self):
#
# c:\Users\Vikram.Vadhirajan\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     392             params = {}
#     393         params["id"] = self._id
# --> 394         return self._parent.execute(command, params)
#     395
# ...

# %%
df
# Out:
#   Sl.No                                  Link  \
# 0     1  https://www.amazon.com/dp/B013USOP5O
#
#                                                Image
# 0  https://m.media-amazon.com/images/I/71WfYN0DGZ...

# %%
df.to_excel('First Available.xlsx', index=False)
