# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver import ActionChains
import pandas as pd
import datetime
import warnings
from tqdm import tqdm
import numpy as np
from IPython.display import clear_output
# Ignore all warnings (not recommended in general)
warnings.filterwarnings("ignore")
import os

# %%
path= 'C://chromedriver.exe'
driver=webdriver.Chrome()
wait=WebDriverWait(driver, 15)
driver.maximize_window()

# %% [markdown]
# ## Orielly

# %%
driver.get('https://supplyline.oreillyauto.com/SupplyLineLogin/home')

# %%
username_field = driver.find_element(By.ID,'userId')  
username_field.send_keys('v0asaru')
password_field = driver.find_element(By.ID,'userp')  
password_field.send_keys('Jan2025!')
button = driver.find_element(By.ID, "loginButton")
button.click()

# %%
driver.find_elements(By.ID,'navbarDropdown')[2].click()
driver.find_element(By.XPATH,"//div/a[text()='General']").click()
sleep(3)

# %%
Brandlist=["Brake Parts Inc LLC",
           "Cardone Industries Inc",
           "Carter Fuel Systems LLC",
           "Champion Laboratories Inc",
           "Fram Group Operations LLC",
           "Hopkins Manufacturing Corporation",
           "Horizon Global Americas Inc",
           "International Brake Industries Inc",
           "Trico Products Corp",
           "ASC Industries Inc"]

# %%
for Brand in Brandlist:
    driver.find_element(By.ID,"enterpriseSelector").click()
    sleep(1)
    driver.find_element(By.CSS_SELECTOR,f'[value="{Brand}"]').click()
    sleep(3)
    driver.find_element(By.CSS_SELECTOR,'[data-folder="Scheduled Reports"]').click()
    search=driver.find_element(By.ID,"folderSearchBar")
    search.click()
    search.send_keys('WarrantyByItem')
    sleep(1)
    driver.find_elements(By.CSS_SELECTOR,'[role="row"]')[1].click()

# %% [markdown]
# ## NAPA

# %%
driver.get('https://saml2.genpt.com/?SAMLRequest=fZFPT8MwDMW%2FSpV7%2FyzruhK1lSY2pEmAgCIOXFCWmi1Sm5TYnfbxSTsxbReOtt6zf88uUHZtL1YDHcwb%2FAyAFGzXJfu6SxsuVb4MYaGaMG0WeZgnyybcqSbNs4wv53nCgg9wqK0pGY98tUUcYGuQpCHfSjgPkzTk%2FJ3PBM9EkkXzxScL1n6JNpIm44GoRxHHIweP9mB6ipTtYhY8WKdgAivZt2wRxgUvElEf4dJZIYIbJ91bg0MHrgZ31MpTNHDyDF5B5PRuIDgrtNnfSmYsOHWtQTFdomSDM8JK1CiM7AAFKVGvnh6FTyh6Z8kq27KqGNViCuyu%2FP%2Fb5R8sq17rzXO9KeKrMdW5un1G9Qs%3D&RelayState=fe96ab3a-b027-4f05-b809-748453349dc8&SigAlg=http%3A%2F%2Fwww.w3.org%2F2000%2F09%2Fxmldsig%23rsa-sha1&Signature=ldTIF54ERFcL%2BPXCDa%2BR9PBZsQVAILKpUkRpyUDakAEFzan4HfJJcabvuU9q0f601I9A3OSK8BxttM0CRhXFfn3AL5vwo6L%2BNQqsjPw6GsYclcIB4jIKFb5zeBfT9M%2BuBB4NJBi9azUkYjNtGYirxowkMizhXehsB74WMh3BTFRiwMOrsTQKf0pOCcqDmP5RC%2FtJ90YMfZ6zU206HsG1SOexmNS6JDB4whxhWiX%2FqRvjxdYahfiDAcjasCUd3RUF9WpW3Xk2LG09dvMraPA8399pSiHzn9BRDjkGv5E3wAW95DcsbMtQsKjrwucs9Bcka1ZtY6QNqUakJlJp3R3a5w%3D%3D')

# %%
username_field = driver.find_element(By.CSS_SELECTOR,'[name="TextboxUsername"]')  
username_field.send_keys('UXV051135')

password_field = driver.find_element(By.CSS_SELECTOR,'[name="TextboxPassword"]')  
password_field.send_keys('Dec2024!')

button = driver.find_element(By.CSS_SELECTOR, '[name="ButtonLogin"]')
button.click()
sleep(20)

# %%
driver.find_element(By.CSS_SELECTOR,'[title="Product Analysis"]').click()

# %%
sleep(5)
wait.until(EC.element_to_be_clickable((By.CSS_SELECTOR,'[title="Product Analysis"]'))).click()

wait.until(EC.presence_of_all_elements_located((By.CSS_SELECTOR,'[class="qv-content-item"]')))[2].click()

sleep(10)
len(driver.window_handles)
secondtab=driver.window_handles[1]
firsttab=driver.window_handles[0]
driver.switch_to.window(secondtab)
sleep(15)

# %%
driver.find_element(By.CSS_SELECTOR,'[title="List view"]').click()
sleep(1)
driver.find_element(By.CSS_SELECTOR,'[title="Warranty Percent/Defect Rate Analysis CYTD"]').click()
sleep(10)

# %%
driver.find_element(By.CSS_SELECTOR,'[title="Year Month"]').click()
sleep(1)
driver.find_element(By.CSS_SELECTOR,'[aria-posinset="2"]').click()
driver.find_element(By.CSS_SELECTOR,'[title="Year Month"]').click()

# %%
PET=driver.find_element(By.ID,"khrrXh_title")
action = ActionChains(driver)
action.context_click(PET).perform()
sleep(2)
driver.find_element(By.CSS_SELECTOR,'[id="export-group"]').click()
driver.find_element(By.CSS_SELECTOR,'[title="Data"]').click()
sleep(2)
driver.find_element(By.CLASS_NAME,"export-url").click()

# %%
driver.close()
sleep(1)
driver.switch_to.window(firsttab)
driver.close()

# %%
input("Press Anykey to close")
# Out:
# '1'
