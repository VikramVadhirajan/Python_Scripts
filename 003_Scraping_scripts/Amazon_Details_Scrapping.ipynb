# %% [markdown]
# # 1. Library calling

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd
import datetime
import warnings
from tqdm import tqdm
import numpy as np
from IPython.display import clear_output
# Ignore all warnings (not recommended in general)
warnings.filterwarnings("ignore")
import os

# %%
# !pip install -U pip setuptools wheel
# !pip install -U spacy
# !python -m spacy download en_core_web_sm
# import spacy

# nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# # 2. Defining the Product Information and Location

# %%
SummaryFolder=r'C:\Users\Vikram.Vadhirajan\OneDrive - Trico\FBG\01_DRA\00_Projects\99_Automation_Projects'
summaryFile='Scraping_List.txt'
st=pd.read_csv(SummaryFolder+'\\'+summaryFile)
print(st)
#Define Product to extract
search_text = st['Product Name'][72]
print(search_text)
Source="Amazon"
OFolder=fr'C:\Users\Vikram.Vadhirajan\OneDrive - Trico\FBG\01_DRA\00_Projects\99_Automation_Projects\{Source}\Outputs'
IFolder=fr'C:\Users\Vikram.Vadhirajan\OneDrive - Trico\FBG\01_DRA\00_Projects\99_Automation_Projects\{Source}\Inputs'

filename=Source+'ProductLinks_'+search_text+'.xlsx'
df1=pd.read_excel(IFolder+'\\'+filename)
imagepath=fr"C:\Users\Vikram.Vadhirajan\OneDrive - Trico\Vikram Data research\{search_text}\ProductImage"
if not os.path.exists(imagepath):
    os.makedirs(imagepath)
df1
# Out:
#                            Product Name
# 0                         Ignition Coil
# 1               Windshield Washer Pumps
# 2                 coupler trailer locks
# 3   Adjustable Trailer Hitch Ball Mount
# 4                        Vacuum Cleaner
# ..                                  ...
# 68                  Drum Brake Tool Kit
# 69                  Brake Spring Pliers
# 70               swing away hitch mount
# 71                      Garage Products
# 72                        Oxygen Sensor
#
# [73 rows x 1 columns]
# Oxygen Sensor
#      Unnamed: 0                                 Links  Name       ASINs
# 0             0  https://www.amazon.com/dp/B000XETMW0   NaN  B000XETMW0
# 1             1  https://www.amazon.com/dp/B00GYG3R2W   NaN  B00GYG3R2W
# 2             2  https://www.amazon.com/dp/B000CF3W9O   NaN  B000CF3W9O
# 3             3  https://www.amazon.com/dp/B00EZQK9RY   NaN  B00EZQK9RY
# 4             4  https://www.amazon.com/dp/B000CF3WOY   NaN  B000CF3WOY
# ...

# %%
Linklist=["https://www.amazon.com/dp/B0843CPBCZ",
"https://www.amazon.com/dp/B0843CQDS4",
"https://www.amazon.com/dp/B0BKQZSRLP",
"https://www.amazon.com/dp/B0BTTYN6WN",
"https://www.amazon.com/dp/B0843CPXZR",
"https://www.amazon.com/dp/B0BTTYWFGN",
"https://www.amazon.com/dp/B0843CW16D",
"https://www.amazon.com/dp/B0843CQFRT",
"https://www.amazon.com/dp/B0843D1DSD",
"https://www.amazon.com/dp/B0843CV98Z",
"https://www.amazon.com/dp/B0843D1QDV",
"https://www.amazon.com/dp/B0843CV983",
"https://www.amazon.com/dp/B0843D88MX",
"https://www.amazon.com/dp/B0843D1DQV",
"https://www.amazon.com/dp/B0843CPBB7",
"https://www.amazon.com/dp/B0843D56R1",
"https://www.amazon.com/dp/B0843CQ9GR",
"https://www.amazon.com/dp/B00LEBK96O",
"https://www.amazon.com/dp/B0BTTXRGMH",
"https://www.amazon.com/dp/B0B15LZQ74",
"https://www.amazon.com/dp/B0843D6G3B",
"https://www.amazon.com/dp/B0843D2QGW",
"https://www.amazon.com/dp/B0843CTC2Q",
"https://www.amazon.com/dp/B0843CYX5D",
"https://www.amazon.com/dp/B0843CT6D6",
"https://www.amazon.com/dp/B0843CWLVL",
"https://www.amazon.com/dp/B0843D88NM",
"https://www.amazon.com/dp/B0BWLV6LLP",
"https://www.amazon.com/dp/B0BWLHN1VG",
"https://www.amazon.com/dp/B0B15N6481",
"https://www.amazon.com/dp/B0BKR2NGBC",
"https://www.amazon.com/dp/B0BWLY1N6Y",
"https://www.amazon.com/dp/B099DFFHPY",
"https://www.amazon.com/dp/B0B1W2QVMN"]

# %%
df1=pd.DataFrame(Linklist,columns=['Links'])

# %%
df1.loc[1,"Name"]
# Out:
# nan

# %%
length=len(df1)
print(length)
# Out:
# 216

# %% [markdown]
# # 3. Setting Webdriver and Website Specific Information

# %%
path= 'C://chromedriver.exe'
driver=webdriver.Chrome()
wait=WebDriverWait(driver, 5)
driver.get('https://www.amazon.com/')

# %%
location = driver.find_element(By.ID, 'nav-global-location-popover-link')

location.click()
sleep(3)
pin = driver.find_element(By.ID, 'GLUXZipUpdateInput')
pinnumber='94203'
pin.send_keys(pinnumber)

apply=driver.find_element(By.CSS_SELECTOR, 'span.a-button-inner[data-action="GLUXPostalUpdateAction"]')
apply.click()

# %% [markdown]
# # 4. Defining the Dataframe and Extracting the data into the Dataframe

# %%
cols =['Sl.No','Attributes','Short_Details','Variants'] #,'Review_Mentions','Standards'
df = pd.DataFrame(columns=cols)
df
count=0

# %%
driver.get(df1["Links"][0])

# %%
for i in tqdm(range(length)):
    driver.get(df1["Links"][i])
    print(i)
    df.loc[count,'Sl.No']=int(i)
    sleep(3)
    try:
        df.loc[count,'Name']=driver.find_element(By.XPATH, "//span[@class='a-size-large product-title-word-break']").text
        df.loc[count,'Links']=df1["Links"][i]
        try:
            pricetopay=float(driver.find_element(By.CLASS_NAME, "priceToPay").text.replace('''\n''','.').replace('$','').replace(',',''))
            df.loc[count,'Current Price']=pricetopay
        except:
            pass
        try:
            listprice=float(driver.find_element(By.CLASS_NAME, "a-text-price").text.replace('''\n''','.').replace('$','').replace(',',''))
            df.loc[count,'List Price']=listprice
        except:
            try:
                df.loc[count,'List Price']=pricetopay
            except:
                pass
        try:
            df.loc[count,'Rating']=float(driver.find_element(By.ID, "averageCustomerReviews").text.split("\n")[0])
        except:
            df.loc[count,'Rating']=0               
        try:
            df.loc[count,'No of Ratings']=int(driver.find_element(By.ID, "acrCustomerReviewText").text.split(' ')[0].replace(",",""))
        except:
            df.loc[count,'No of Ratings']=0
        try:
            df.loc[count,"Product Description"]=(driver.find_element(By.XPATH, "(//div[@id='productDescription'])").text)
        except:
            df.loc[count,"Product Description"]=0

        Alist=[]
        try:
            table=driver.find_element(By.CSS_SELECTOR,'[id="productDetails_techSpec_section_1"]')
            Values=table.find_elements(By.TAG_NAME, "tr")
            for row in Values:
                # Extract data from columns (td/th elements)
                l=row.find_element(By.TAG_NAME, "th").text
                v=row.find_element(By.TAG_NAME, "td").text
                Alist.append(l+":"+v)
        except:
            pass
        try:
            table=driver.find_element(By.CSS_SELECTOR,'[id="productDetails_detailBullets_sections1"]')
            Values=table.find_elements(By.TAG_NAME, "tr")
            for row in Values:
                # Extract data from columns (td/th elements)
                l=row.find_element(By.TAG_NAME, "th").text
                v=row.find_element(By.TAG_NAME, "td").text
                Alist.append(l+":"+v)
        except:
            attrs=driver.find_element(By.CSS_SELECTOR,'[id="detailBulletsWrapper_feature_div"]').find_elements(By.CSS_SELECTOR,'[class="a-list-item"]')
            for att in attrs:
                Alist.append(att.text)
        df.at[count,'Attributes']=Alist
        variants=[]
        try:
            vs=len(driver.find_elements(By.CSS_SELECTOR,'[class="twisterSlotDiv "]'))
            for n in range(vs):

                variant=driver.find_elements(By.CSS_SELECTOR,'[class="twisterTextDiv text"]')[n].text
                cost=(driver.find_elements(By.CSS_SELECTOR,'[class="twisterSlotDiv "]')[n].text)
                ASIN=(driver.find_element(By.CSS_SELECTOR,f'[id="size_name_{n}"]').get_attribute('data-defaultasin'))
                v=variant+" :|: "+cost+" :|: "+ASIN
                variants.append(v)
            print(variants)
            sleep(1)
            df.at[count,'Variants']=variants
        except:
            df.at[count,'Variants']=""

        try:
            df.loc[count,'Sales_LastMonth']=int(driver.find_element(By.ID, "social-proofing-faceout-title-tk_bought").text.split("+")[0].replace('K','000'))
        except:
            df.loc[count,'Sales_LastMonth']=0
        try:
            df.loc[count,'Details']=driver.find_element(By.XPATH, "(//div[@class='a-section a-spacing-medium a-spacing-top-small'])").text
        except:
            pass
        D_s=[]
        try:
            ls=driver.find_elements(By.CSS_SELECTOR,'[class="a-span3"]')
            vs=driver.find_elements(By.CSS_SELECTOR,'[class="a-span9"]')
            for l,v in zip(ls,vs):
                D_s.append(l.text+":"+v.text)
        except:
            pass
        try:
            es=driver.find_elements(By.CLASS_NAME,"a-normal")
            os= es[2].find_elements(By.CLASS_NAME,"a-text-bold")
            vs=es[2].find_elements(By.CSS_SELECTOR,'[class="a-size-base handle-overflow"]')
            for o, v  in zip( os, vs):
                D_s.append(o.text+":"+v.text)
        except:
            pass
        try:
            Atts=driver.find_elements(By.CSS_SELECTOR,'[class="a-span6"]')
            for att in Atts:
                vals=att.text.replace("\n",':')
                D_s.append(vals)
        except:
            pass

        df.at[count,"Short_Details"]=D_s
        try:
            df.loc[count,'Product_Category']=driver.find_element(By.CSS_SELECTOR,'[class="a-unordered-list a-horizontal a-size-small"]').text.rsplit('\n')[-1]
        except:
            pass
        try:
            df.loc[count,'ReviewSummary']=driver.find_element(By.CSS_SELECTOR,'[id="product-summary"]').text
        except:
            pass
        try:
            df.loc[count,'FirstAvailableDate']=driver.find_element(By.XPATH, "//th[contains(text(), 'Date First Available')]").find_element(By.XPATH, "./following-sibling::td").text
        except:
            pass
        try:
            elements=driver.find_elements(By.CSS_SELECTOR, '[data-csa-c-action="infoPopOver"]')
            len(elements)
            slist=[]
            for element in elements:
                s=element.get_attribute('data-csa-c-item-id')
                slist.append(s)
            #print(slist)
            df.at[count,"Sentiment"]=slist
        except:
            df.loc[count,'Sentiment']=""
        try: 
            filename=df1["Links"][i].split("/")[-1]+".jpg" # Extract filename from URL (modify if needed)
            t=driver.find_element(By.CSS_SELECTOR,'[id="landingImage"]')
            s=t.get_attribute('src')
            import requests

            # Download the image using requests
            response = requests.get(s, stream=True)

            if response.status_code == 200:            
                savepath=imagepath+"\\"+str(i)+"_"+filename
                df.loc[count,'ImageName']=str(i)+"_"+filename
            # Get filename from URL or generate a unique one
                with open(savepath, 'wb') as f:
                    for chunk in response.iter_content(1024):
                        f.write(chunk)
                print(f"Image downloaded: {filename}")
            else:
                print(f"Failed to download image: {s}")
        except:
            print(f"part number not available for {filename}")
        count=count+1
        balanceitem=length-i
        #print(balanceitem)
        #timeremaining(balanceitem,i)
        clear_output(wait=True)
    except:
        continue
# Out:
# 100%|██████████| 216/216 [30:27<00:00,  8.46s/it]

# %%
print(df.shape)
df.tail()
# Out:
# (215, 17)
#     Sl.No                                         Attributes  \
# 210   211  [Brand:Trico, Vehicle Service Type:Car, Item L...
# 211   212  [Brand:Trico, Vehicle Service Type:Truck, Item...
# 212   213  [Brand:Trico, Vehicle Service Type:Car, Item L...
# 213   214  [Brand:Trico, Vehicle Service Type:Car, Mounti...
# 214   215  [Brand:Trico, Vehicle Service Type:Car, Mounti...
#
#                                          Short_Details Variants  \
# 210  [Brand:Trico, Vehicle Service Type:Car, Item L...       []
# 211  [Brand:Trico, Vehicle Service Type:Truck, Item...       []
# 212  [Brand:Trico, Vehicle Service Type:Car, Item L...       []
# 213  [Brand:Trico, Vehicle Service Type:Car, Mounti...       []
# 214  [Brand:Trico, Vehicle Service Type:Car, Mounti...       []
#
#                                                   Name  \
# 210  TRICO Gold 3-Piece Driver/Passenger/Rear All-W...
# 211  TRICO Truck™ (58-22225) 22 Inch Pack of 2 Auto...
# ...

# %% [markdown]
# # 5. Post Processing Data and Exporting

# %%
namesplit=search_text.split(" ")
print(namesplit)
# Out:
# ['Oxygen', 'Sensor']

# %%
df['Name_Clean']=df['Name'].str.lower().str.replace("compatible with","").str.replace('w/',"with ")
for i in range(len(df)):
    if namesplit[0] in df['Name_Clean'][i] and namesplit[1] in df['Name_Clean'][i]and namesplit[2] in df['Name_Clean'][i]and namesplit[3] in df['Name_Clean'][i]and namesplit[1] in df['Name_Clean'][4]:
        df.loc[i,'Product']=search_text
    else:
        df.loc[i,"Product"]="Other Product"
del df['Name_Clean']

# %%
#df = df[(df['Current Price'] > 0)]

# %%
df['Short_Details'][1]
# Out:
# ['Brand:Bosch',
#  'Item dimensions L x W x H:5.9 x 2.3 x 2.2 inches',
#  'Material:Stainless Steel',
#  'Style:Oxygen Sensor',
#  'Mounting Type:Flange Mount']

# %%
df['Material']=df['Short_Details'].apply(lambda x: str(x).replace('[','').replace(']','').replace('\'', '').replace(' ','')).str.split('Material:',expand=True)[1].str.split(''',''',expand=True)[0]
df['ASIN']=df['Links'].str.split('dp/',expand=True)[1]
df=df.drop_duplicates(subset=['Links'])

# %%
df['Part Number']=df["Attributes"].apply(lambda x: str(x).replace('[','').replace(']','').replace('\'', '').replace(' ','')).str.split('ManufacturerPartNumber:',expand=True)[1].str.split(',',expand=True)[0]
df['Brand']=df["Attributes"].apply(lambda x: str(x).replace('[','').replace(']','').replace('\'', '').replace(' ','')).str.split('Brand:',expand=True)[1].str.split(',',expand=True)[0]
df['Manufacturer']=df["Attributes"].apply(lambda x: str(x).replace('[','').replace(']','').replace('\'', '').replace(' ','')).str.split('Manufacturer:',expand=True)[1].str.split(',',expand=True)[0]
df['Source']="Amazon"
df[['Rating',"No of Ratings","Sales_LastMonth",'Manufacturer','Material','Part Number', "Brand","Source"]].head()
# Out:
#    Rating  No of Ratings  Sales_LastMonth Manufacturer        Material  \
# 0     4.6         2154.0            300.0        Lisle            None
# 1     4.5         2431.0              0.0        Bosch  StainlessSteel
# 2     4.5         2431.0              0.0           No  StainlessSteel
# 3     4.5         2431.0            100.0        Bosch  StainlessSteel
# 4     4.5         2431.0              0.0           No  StainlessSteel
#
#   Part Number  Brand  Source
# 0       12230  Lisle  Amazon
# 1        None   None  Amazon
# 2        None   None  Amazon
# 3        None   None  Amazon
# 4        None   None  Amazon

# %%
cols=["Sl.No",
"Name",
"Product",
'Product_Category',
"Current Price",
"List Price",
"Rating",
"No of Ratings",
"Short_Details",
"Details",
"Product Description",
"Sales_LastMonth",
"Attributes",
"Brand",
"Part Number",
'Variants',
"Manufacturer",
"ReviewSummary",
"FirstAvailableDate",
"Sentiment",
"Material",
"ASIN",
"Links",
"Source",
"ImageName"
] #'Standards',
df=df[cols]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sl.No                500 non-null    object
#  1   Name                 500 non-null    object
#  2   Product              500 non-null    object
#  3   Product_Category     500 non-null    object
#  4   Current Price        498 non-null    float64
#  5   List Price           500 non-null    float64
#  6   Rating               500 non-null    float64
#  7   No of Ratings        500 non-null    float64
#  8   Short_Details        500 non-null    object
#  9   Details              500 non-null    object
#  10  Product Description  500 non-null    object
#  11  Sales_LastMonth      500 non-null    float64
#  12  Attributes           500 non-null    object
#  13  Brand                253 non-null    object
#  14  Part Number          251 non-null    object
# ...

# %%
print(df.shape)
df.head()
# Out:
# (500, 25)
#   Sl.No                                               Name        Product  \
# 0     0    Lisle 12230 Oxygen Sensor Thread Chaser , Black  Other Product
# 1     1  Bosch 18121 OE Fitment Wideband Oxygen Sensor ...  Other Product
# 2     2  BOSCH 15680 Premium Original Equipment Oxygen ...  Other Product
# 3     3  BOSCH 17323 Premium Original Equipment Oxygen ...  Other Product
# 4     4  BOSCH 17215 Premium Original Equipment Oxygen ...  Other Product
#
#   Product_Category  Current Price  List Price  Rating  No of Ratings  \
# 0           Oxygen           8.04       11.99     4.6         2154.0
# 1           Oxygen         136.50      136.50     4.5         2431.0
# 2           Oxygen          66.50      126.21     4.5         2431.0
# 3           Oxygen          72.99       92.99     4.5         2431.0
# 4           Oxygen         117.25      206.99     4.5         2431.0
#
#                                        Short_Details  \
# ...

# %%
dfAtt=df[['ASIN','Attributes']]
dfAtt=dfAtt.explode('Attributes')
dfAtt[['Attributes', 'Value']] = dfAtt['Attributes'].str.split(':',1, expand=True)

# %%
summary_df = pd.pivot_table(dfAtt, values='Value', index='Attributes',aggfunc='count').reset_index()
summary_df =summary_df.sort_values(by='Value',ascending=False)
summary_df=summary_df.rename(columns ={'Value':'No Products contains this Attribute'})
summary_df
# Out:
#                                          Attributes  \
# 64                                Best Sellers Rank
# 71                                 Customer Reviews
# 86                                      Item Weight
# 91                                     Manufacturer
# 58                                             ASIN
# ..                                              ...
# 36     #45 in Automotive Replacement Oxygen Sensors
# 35     #44 in Automotive Replacement Oxygen Sensors
# 34    #426 in Automotive Replacement Oxygen Sensors
# 33    #425 in Automotive Replacement Oxygen Sensors
# 0   #1,173 in Automotive Replacement Oxygen Sensors
#
#     No Products contains this Attribute
# 64                                  500
# 71                                  498
# 86                                  300
# 91                                  254
# 58                                  254
# ..                                  ...
# 36                                    0
# ...

# %%
# !pip install -U pip setuptools wheel
# !pip install -U spacy
# !python -m spacy download en_core_web_sm
# import spacy

# nlp = spacy.load("en_core_web_sm")  
# for i in range(length):
#     try:
#         texts=df["Name"][i]
#         doc=nlp(texts)
#         standard_Lists=[]
#         for entity in doc.ents:        
#             if entity.label_=="ORG":
#                 standard_Lists.append(entity.text)
#         df.at[i, 'Standards']=standard_Lists
#     except:
#         pass

# %%
with pd.ExcelWriter(OFolder+'\\'+f'{Source}ProductDetails_'+search_text+'.xlsx') as writer:  # doctest: +SKIP
    df.to_excel(writer,index=False, sheet_name='Raw')
    summary_df.to_excel(writer,index=False, sheet_name='Attribute_Summary')
    dfAtt.to_excel(writer,index=False, sheet_name='Attribute_Values')

# %%
with pd.ExcelWriter(imagepath+'\\'+f'{Source}ProductDetails_'+search_text+'.xlsx') as writer:  # doctest: +SKIP
    df.to_excel(writer,index=False, sheet_name='Raw')
    summary_df.to_excel(writer,index=False, sheet_name='Attribute_Summary')
    dfAtt.to_excel(writer,index=False, sheet_name='Attribute_Values')

# %% [markdown]
# # 99. Archived Codes

# %%
#Downloading images from amazon.
from selenium import webdriver
from selenium.webdriver.common.by import By
import openpyxl
import requests
from io import BytesIO
from openpyxl import Workbook
from openpyxl.drawing.image import Image

#--------------------------------------------------------------------------------------------------------------------------
il=[]
for i in range(length):
    driver.get(links[i])
    imagelink=driver.find_element(By.ID,"landingImage").get_attribute('src')
    il.append(imagelink)
    response = requests.get(imagelink)
    img_data = BytesIO(response.content)
    ASIN=links[i].split('dp/')[1]
    img_filename = f"{ASIN}.jpg"
    with open(img_filename, "wb") as img_file:
        img_file.write(img_data.getvalue())
    # # Create a DataFrame
    # df = pd.DataFrame({'Product Image URL': [imagelink]})
    # df.loc[count,'ASIN']=ASIN
    # # Save the DataFrame to an Excel file
    # excel_filename = "product_data.xlsx"
    # df.to_excel(excel_filename, index=False,)
    # wb = Workbook()
    # ws = wb.active
    # img = Image(img_filename)
    # ws.add_image(img, f'C{count+2}')
    # wb.save(excel_filename)
    balanceitem=length-i
    timeremaining(balanceitem,i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12612\472669860.py in <module>
#      10 #--------------------------------------------------------------------------------------------------------------------------
#      11 il=[]
# ---> 12 for i in range(length):
#      13     driver.get(links[i])
#      14     imagelink=driver.find_element(By.ID,"landingImage").get_attribute('src')
#
# NameError: name 'length' is not defined
