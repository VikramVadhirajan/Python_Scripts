# %% [markdown]
# # 1. Library calling

# %%
import pandas as pd
import warnings
# Ignore all warnings (not recommended in general)
warnings.filterwarnings("ignore")

# %% [markdown]
# # 2. Defining the Product Information and Location

# %%
SummaryFolder=r'C:\Users\Vikram.Vadhirajan\OneDrive - Trico\FBG\01_DRA\00_Projects\99_Automation_Projects'
summaryFile='Scraping_List.txt'
st=pd.read_csv(SummaryFolder+'\\'+summaryFile)
print(st)
#Define Product to extract
search_text = st['Product Name'][12]
search_text= 'Armorillo Tonneau Cover'
print(search_text)
Source="Amazon"
IFolder=fr'C:\Users\Vikram.Vadhirajan\OneDrive - Trico\FBG\01_DRA\00_Projects\99_Automation_Projects\{Source}\Inputs'
OFolder=fr'C:\Users\Vikram.Vadhirajan\OneDrive - Trico\FBG\01_DRA\00_Projects\99_Automation_Projects\{Source}\Outputs'
filename='_Link.txt'
f=open(IFolder+'\\'+search_text+filename,'r')
Linebraker='product-grid-item'
prefix='https://www.amazon.com/'
# Out:
#                                   Product Name
# 0                                Ignition Coil
# 1                      Windshield Washer Pumps
# 2                        coupler trailer locks
# 3          Adjustable Trailer Hitch Ball Mount
# 4                               Vacuum Cleaner
# 5                                   Spark Plug
# 6              bluetooth Enabled Trailer locks
# 7                          Power Steering Hose
# 8   Power Steering Pressure Line Hose Assembly
# 9                       Washer Fluid Reservoir
# 10          Hitch Ball Mount with Weight Scale
# 11                               LED Headlamps
# 12                             LED flashlights
# 13                   Fiberglass Tonneau Covers
# 14                    Aluminium Tonneau Covers
# 15                     Hardfold Tonneau Covers
# 16                            Spark Plug Wires
# 17                 washer fluid reservoir tank
# Armorillo Tonneau Cover

# %% [markdown]
# # 3. Setting Webdriver and Website Specific Information

# %%
content=f.read()

# %%
List=content.split(Linebraker)

# %%
print(len(List))
# Out:
# 124

# %% [markdown]
# # 4. Defining the Dataframe and Extracting the data into the Dataframe

# %%
cols =['Sl.No'] #,'Review_Mentions'
df = pd.DataFrame(columns=cols)

# %%
prefix+List[11].split('href="')[1].split('?ref')[0]
# Out:
# 'https://www.amazon.com//Armordillo-USA-7162839-Tri-Fold-2016-2020/dp/B08G3VDGQL'

# %%
count=0
for i in range(1,len(List)):
    df.loc[count,'Sl.No']=i
    df.loc[count,'Current Price']=List[i].split('current price')[1].split ('</span>')[0].replace('Now',"").replace('$',"")
    try:
        df.loc[count,'List Price']=List[i].split('<div class="gray mr1 strike f6 f4-l flex items-end mt1" aria-hidden="true">')[1].split('</div>')[0].replace('$',"")
    except:
        df.loc[count,'List Price']=List[i].split('current price')[1].split ('</span>')[0].replace('Now',"").replace('$',"").replace(' ',"")
    Rating=List[i].split(' out of 5 Stars')[0].rsplit('<span class="w_iUH7">')[-1]
    if len(Rating)>3:
        df.loc[count,'Rating']=0
    else:
        df.loc[count,'Rating']=Rating
    try:
        df.loc[count,'No of Ratings']=List[i].split(' review')[0].split('5 Stars. ')[1]
    except:
        df.loc[count,'No of Ratings']=0
    df.loc[count,'Name']=List[i].split(' f6 f5-l lh-copy">')[1].split('</span>')[0]
    try:
        link=List[i].split('''%2Fip%2F''')[1].split('''%3F''')[0].replace('''%2F''','''/''')
    except:
        link=List[i].split('''target="" href="/ip/''')[1].split('''?''')[0]
    df.loc[count,'Links']=prefix+link
    df.loc[count,'Source']=Source
    df.loc[count,'Product']=search_text
    count=count+1

# %%
df
# Out:
#     Sl.No Current Price List Price Rating No of Ratings  \
# 0       1         13.99      19.99      4            69
# 1       2         12.99      16.14    4.8           152
# 2       3         16.99      59.99    4.6          1132
# 3       4         12.99      16.14    4.8           152
# 4       5          1.88       1.88    4.6           751
# ..    ...           ...        ...    ...           ...
# 252   253         18.99      18.99      0             0
# 253   254         21.00      25.77    3.3             4
# 254   255         19.65      31.15    4.3             8
# 255   256         19.36      19.36      5             2
# 256   257         35.99      35.99      5             1
#
#                                                   Name  \
# 0    HKEEY Flashlights, LED Tactical Flashlight, 5 ...
# 1    LE 2-Packs LED Flash Light LE1000 High Lumens,...
# 2    100000 Lumens Powerful Flashlight, Rechargeabl...
# 3    LE 2-Packs LED Flash Light LE1000 High Lumens,...
# 4    Ozark Trail Single Mini Handheld LED Flashligh...
# ..                                                 ...
# 252  TORCHSTAR Adjustable LED Headlamp, Extra Brigh...
# 253  Energizer HDL20 Multi-Colored LED Headlamp, Ba...
# 254          Dorcy 400 Lumens, Battery Camping Lantern
# 255                    Cyclops LED 400 lumens Headlamp
# 256  Walmart Beam: 2-in-1 LED Solar Powered Headlam...
#
#                                                  Links   Source  \
# 0    https://www.walmart.com//ip/HKEEY-Flashlights-...  Walmart
# 1    https://www.walmart.com//ip/LE-2-Packs-LED-Fla...  Walmart
# 2    https://www.walmart.com//ip/100000-Lumens-Powe...  Walmart
# 3    https://www.walmart.com//ip/LE-2-Packs-LED-Fla...  Walmart
# 4    https://www.walmart.com//ip/Ozark-Trail-Single...  Walmart
# ..                                                 ...      ...
# 252  https://www.walmart.com//ip/TORCHSTAR-Adjustab...  Walmart
# 253  https://www.walmart.com//ip/Energizer-HDL20-Mu...  Walmart
# 254  https://www.walmart.com//ip/Dorcy-400-Lumens-B...  Walmart
# 255  https://www.walmart.com//ip/Cyclops-LED-400-lu...  Walmart
# 256  https://www.walmart.com//ip/Walmart-Beam-2-in-...  Walmart
#
#              Product
# 0    LED flashlights
# 1    LED flashlights
# 2    LED flashlights
# 3    LED flashlights
# 4    LED flashlights
# ..               ...
# 252  LED flashlights
# 253  LED flashlights
# 254  LED flashlights
# 255  LED flashlights
# 256  LED flashlights
#
# [257 rows x 9 columns]

# %% [markdown]
# # 5. Post Processing Data and Exporting

# %%
df['Sl.No']=df['Sl.No'].astype(int)
df['List Price']=(df['List Price']).astype(float)
df['Current Price']=(df['Current Price']).astype(float)
df['Rating']=(df['Rating']).astype(float)
df['No of Ratings']=(df['No of Ratings']).astype(float)

# %%
cols=["Sl.No",
"Name",
"Product",
"Current Price",
"List Price",
"Rating",
"No of Ratings",
"Links",
"Source"
]
df = df[cols]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 257 entries, 0 to 256
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.No          257 non-null    int32
#  1   Name           257 non-null    object
#  2   Product        257 non-null    object
#  3   Current Price  257 non-null    float64
#  4   List Price     257 non-null    float64
#  5   Rating         257 non-null    float64
#  6   No of Ratings  257 non-null    float64
#  7   Links          257 non-null    object
#  8   Source         257 non-null    object
# dtypes: float64(4), int32(1), object(4)
# memory usage: 27.2+ KB

# %%
df.to_excel(OFolder+'\\'+f'{Source}ProductDetails_'+search_text+'.xlsx', index=False)

# %% [markdown]
# # 99. Archived Codes
