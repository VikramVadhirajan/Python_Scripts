# %%
# %pip install pyspark
# #pip install delta-spark

# %%
from pyspark.sql.functions import * # imports all the functions to avoid initiation of all function separately.

import pandas as pd

# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder.master("local[*]").getOrCreate()
print(f'Spark Version: {spark.version}') # Finding the Spark version to start the session as well.
# Out:
# Spark Version: 3.5.1

# %%
filepath=r"C:\Users\Vikram.Vadhirajan\OneDrive - Trico\FBG\01_DRA\00_Projects\99_Automation_Projects\94_VIO_DATA\INPUT\first_brands_us_veh_aces_202407.csv.gz" # Group Member- C Vikram Vadhirajan
sdf = spark.read.csv(filepath,header=True, inferSchema=True) #Making header true as we have the header information available in the file. .

# %%
sdf.show(10)
# Out:
# +------------+--------------------+-------------+--------------------+----------+--------+----------+----+--------------------+----------+---------+---------+---------------+----------------+-----------+--------------------+------------------+------------+--------------------+------+---------------------+---------------------+--------------------+----------+---------------------+------------+-----------------+--------------+-----+----------+---------------+-------+-------+--------+------------+---------------+------------+----------------+----------+-------+--------+--------+-------------+-------------+------------+-----------------+-------------+---------+---------------+------------------+--------------------+---------+----------------+-------------+--------------+----------------+----------------+---------------------+-----------+
# ...

# %%
rowcount=sdf.count()
colcount=len(sdf.columns)
print(f'Number of Rows: {rowcount} and Number of Columns: {colcount}')
# Out:
# Number of Rows: 662177 and Number of Columns: 59

# %%
df=sdf.toPandas()

# %%
df
# Out:
#        VEHICLE TYPE                 VEHICLE ORIGIN           MAKE  \
# 0               CAR  IMPORT BUILT IN NORTH AMERICA         SUBARU
# 1               CAR                       DOMESTIC      CHEVROLET
# 2       LIGHT TRUCK                       DOMESTIC      CHEVROLET
# 3       LIGHT TRUCK                         IMPORT  MERCEDES-BENZ
# 4       LIGHT TRUCK                       DOMESTIC           FORD
# ...             ...                            ...            ...
# 662172          CAR  IMPORT BUILT IN NORTH AMERICA         NISSAN
# 662173  LIGHT TRUCK                       DOMESTIC      CHEVROLET
# 662174          CAR                         IMPORT           AUDI
# 662175  LIGHT TRUCK                         IMPORT         NISSAN
# 662176          CAR  IMPORT BUILT IN NORTH AMERICA          MAZDA
#
#                    MANUFACTURER  YEAR MODEL     MODEL       TRIM LEVEL  GVW  \
# 0                        SUBARU        2018    LEGACY            SPORT  NaN
# ...

# %%
Folder=r'C:\Users\Vikram.Vadhirajan\OneDrive - Trico\Vikram Data research\VIO_DATA'
Date="202407"

# %%
with pd.ExcelWriter(Folder+'\\'+Date+'_VIO_DATA_USA.xlsx') as writer:  # doctest: +SKIP
    df.to_excel(writer,index=False, sheet_name='Raw')
