# %%
import os
import pandas as pd
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')
import re
import openpyxl
import numpy as np
import os
import pandas as pd
import json

# %%
folder_path=r"C:\03_FBG_Work\89_Autocare_Extract\VCdb"

# %%
import os
import zipfile
import json
import pandas as pd

dataframes = {}

# Get all ZIP files and sort by filename
zip_files = sorted(
    [f for f in os.listdir(folder_path) if f.endswith('.zip')],
    reverse=True  # Latest name comes first
)

if not zip_files:
    print("No ZIP files found.")
else:
    latest_zip_name = zip_files[0]
    latest_zip_path = os.path.join(folder_path, latest_zip_name)
    print(f"Loading from latest ZIP file (by name): {latest_zip_name}")

    with zipfile.ZipFile(latest_zip_path, 'r') as z:
        for file_name in z.namelist():
            if file_name.endswith('.json'):
                try:
                    with z.open(file_name) as f:
                        data = json.load(f)

                    df = pd.json_normalize(data)
                    key = os.path.splitext(os.path.basename(file_name))[0]
                    dataframes[key] = df

                except json.JSONDecodeError as e:
                    print(f"JSON decoding failed for {file_name}: {e}")
                except Exception as e:
                    print(f"Failed to load {file_name}: {e}")
# Out:
# Loading from latest ZIP file (by name): AutoCare_VCdb_NA_MDHD_enUS_JSON_20250529.zip

# %%
df=(dataframes['BaseVehicle']
.merge(dataframes['Vehicle'],how='outer')
.merge(dataframes['Make'],how='outer')
.merge(dataframes['Model'],how='outer')
.merge(dataframes['VehicleType'],on='VehicleTypeID',how='outer')
.merge(dataframes['VehicleToEngineConfig'],on='VehicleID',how='outer')
.merge(dataframes['EngineConfig'],on='EngineConfigID',how='outer')
.merge(dataframes['Valves'],on='ValvesID',how='outer')
.merge(dataframes['Aspiration'],on='AspirationID',how='outer')
.merge(dataframes['EngineDesignation'],on='EngineDesignationID',how='outer')
.merge(dataframes['EngineVIN'],on='EngineVINID',how='outer')
.merge(dataframes['VehicleToDriveType'],on='VehicleID',how='outer')
.merge(dataframes['DriveType'],on='DriveTypeID',how='outer')
.merge(dataframes['EngineBase'],on='EngineBaseID',how='outer')
.merge(dataframes['FuelType'],on='FuelTypeID',how='outer')
.merge(dataframes['VehicleToBrakeConfig'],on='VehicleID',how='outer',suffixes=('_VehicleToBrakeConfig','_VehicleToBrakeConfig2'))
.merge(dataframes['BrakeConfig'],on='BrakeConfigID',how='outer')
.merge(dataframes['BrakeSystem'],on='BrakeSystemID',how='outer')
.merge(dataframes['Region'],on='RegionID',how='outer')
.merge(dataframes['VehicleToClass'],on='VehicleID',how='outer',suffixes=('_VehicleToClass','_VehicleToClass2'))
.merge(dataframes['Class'],on='ClassID',how='outer')
.merge(dataframes['VehicleToWheelbase'],on='VehicleID',how='outer',suffixes=('_VehicleToWheelbase','_VehicleToWheelbase2'))
.merge(dataframes['WheelBase'],left_on='WheelbaseID',right_on='WheelBaseID',how='outer')
.merge(dataframes['VehicleToBodyStyleConfig'],on='VehicleID',how='outer',suffixes=('VehicleToBodyStyleConfig','VehicleToBodyStyleConfig2'))
.merge(dataframes['BodyStyleConfig'],on='BodyStyleConfigID',how='outer')
.merge(dataframes['BodyType'],on='BodyTypeID',how='outer')
.merge(dataframes['EngineVersion'],on='EngineVersionID',how='outer')
)
df
# Out:
#         BaseVehicleID  YearID  MakeID  ModelID  VehicleID  SubmodelID  \
# 0            140370.0  2010.0    40.0   6969.0   238575.0        20.0
# 1            140370.0  2010.0    40.0   6969.0   238575.0        20.0
# 2            140370.0  2010.0    40.0   6969.0   238575.0        20.0
# 3            140370.0  2010.0    40.0   6969.0   238575.0        20.0
# 4            123140.0  2009.0    71.0  22644.0   200021.0        20.0
# ...               ...     ...     ...      ...        ...         ...
# 656310       165517.0  1973.0    40.0  30642.0   333367.0        20.0
# 656311       165544.0  1963.0    40.0  30645.0   333394.0        20.0
# 656312       178544.0  2022.0    47.0  27431.0   394441.0        20.0
# 656313       179526.0  2025.0    47.0  21521.0   412702.0        20.0
# 656314            NaN     NaN     NaN      NaN        NaN         NaN
#
#         RegionID Source_x  PublicationStageID PublicationStageSource  ...  \
# 0            3.0      NaN                 4.0         OE Publication  ...
# 1            3.0      NaN                 4.0         OE Publication  ...
# 2            3.0      NaN                 4.0         OE Publication  ...
# 3            3.0      NaN                 4.0         OE Publication  ...
# 4            1.0      NaN                 4.0             VCDB Batch  ...
# ...          ...      ...                 ...                    ...  ...
# 656310       1.0      NaN                 1.0                         ...
# 656311       1.0      NaN                 1.0                         ...
# 656312       1.0      NaN                 1.0                         ...
# 656313       2.0      NaN                 1.0                         ...
# 656314       NaN      NaN                 NaN                    NaN  ...
#
#        WheelBaseID WheelBase WheelBaseMetric  VehicleToBodyStyleConfigID  \
# 0             69.0     160.5           407.7                    292235.0
# 1             69.0     160.5           407.7                    292235.0
# 2             69.0     160.5           407.7                    292234.0
# 3             69.0     160.5           407.7                    292234.0
# 4              4.0       U/K             U/K                    201107.0
# ...            ...       ...             ...                         ...
# 656310         NaN       NaN             NaN                         NaN
# 656311         NaN       NaN             NaN                         NaN
# 656312         NaN       NaN             NaN                         NaN
# 656313         NaN       NaN             NaN                         NaN
# 656314      1065.0     164.8           418.5                         NaN
#
#        BodyStyleConfigID  Source  BodyNumDoorsID  BodyTypeID  \
# 0                   51.0    None             7.0        28.0
# 1                   51.0    None             7.0        28.0
# 2                  104.0    None            11.0        34.0
# 3                  104.0    None            11.0        34.0
# 4                  108.0    None             4.0        40.0
# ...                  ...     ...             ...         ...
# 656310               NaN     NaN             NaN         NaN
# 656311               NaN     NaN             NaN         NaN
# 656312               NaN     NaN             NaN         NaN
# 656313               NaN     NaN             NaN         NaN
# 656314               NaN     NaN             NaN         NaN
#
#             BodyTypeName  EngineVersion
# 0          Cab & Chassis            N/A
# 1          Cab & Chassis            N/A
# 2       Stripped Chassis            N/A
# 3       Stripped Chassis            N/A
# 4                    U/K            N/A
# ...                  ...            ...
# 656310               NaN            NaN
# 656311               NaN            NaN
# 656312               NaN            NaN
# 656313               NaN            NaN
# 656314               NaN            NaN
#
# [656315 rows x 77 columns]

# %%
df_All=df[['BaseVehicleID',"VehicleTypeName", 'YearID','MakeName','ModelName','BlockType', 'Cylinders','Liter','ValvesPerEngine','CC','CID','FuelTypeName','AspirationName','EngineDesignationName','EngineVINName','DriveTypeName','RegionAbbr','BodyTypeName','WheelbaseID','WheelBase','WheelBaseMetric','EngineVersion','BrakeSystemName']] #"ClassName",
df_All = df_All.drop_duplicates().reset_index(drop=True)
df_All
# Out:
#         BaseVehicleID     VehicleTypeName  YearID       MakeName  \
# 0            140370.0  Medium/Heavy Truck  2010.0          Dodge
# 1            140370.0  Medium/Heavy Truck  2010.0          Dodge
# 2            140370.0  Medium/Heavy Truck  2010.0          Dodge
# 3            140370.0  Medium/Heavy Truck  2010.0          Dodge
# 4            123140.0  Medium/Heavy Truck  2009.0  International
# ...               ...                 ...     ...            ...
# 310695       165517.0  Medium/Heavy Truck  1973.0          Dodge
# 310696       165544.0  Medium/Heavy Truck  1963.0          Dodge
# 310697       178544.0  Medium/Heavy Truck  2022.0      Chevrolet
# 310698       179526.0  Medium/Heavy Truck  2025.0      Chevrolet
# 310699            NaN                 NaN     NaN            NaN
#
#            ModelName BlockType Cylinders Liter ValvesPerEngine    CC  ...  \
# 0           Ram 4000         V         8   5.7              16     -  ...
# 1           Ram 4000         V         8   5.7              16     -  ...
# 2           Ram 4000         V         8   5.7              16     -  ...
# 3           Ram 4000         V         8   5.7              16     -  ...
# 4               3200         V         8   6.4              32  6369  ...
# ...              ...       ...       ...   ...             ...   ...  ...
# 310695          S600       NaN       NaN   NaN             NaN   NaN  ...
# 310696          W500       NaN       NaN   NaN             NaN   NaN  ...
# 310697    LCF 6500XD       NaN       NaN   NaN             NaN   NaN  ...
# 310698  Express 4500       NaN       NaN   NaN             NaN   NaN  ...
# 310699           NaN       NaN       NaN   NaN             NaN   NaN  ...
#
#        EngineDesignationName EngineVINName DriveTypeName RegionAbbr  \
# 0                       HEMI             -           AWD        MEX
# 1                       HEMI             -           RWD        MEX
# 2                       HEMI             -           AWD        MEX
# 3                       HEMI             -           RWD        MEX
# 4                MaxxForce 7             -           U/K        USA
# ...                      ...           ...           ...        ...
# 310695                   NaN           NaN           NaN        USA
# 310696                   NaN           NaN           NaN        USA
# 310697                   NaN           NaN           NaN        USA
# 310698                   NaN           NaN           NaN        CAN
# 310699                   NaN           NaN           NaN        NaN
#
#             BodyTypeName WheelbaseID WheelBase WheelBaseMetric  EngineVersion  \
# 0          Cab & Chassis        69.0     160.5           407.7            N/A
# 1          Cab & Chassis        69.0     160.5           407.7            N/A
# 2       Stripped Chassis        69.0     160.5           407.7            N/A
# 3       Stripped Chassis        69.0     160.5           407.7            N/A
# 4                    U/K         4.0       U/K             U/K            N/A
# ...                  ...         ...       ...             ...            ...
# 310695               NaN         NaN       NaN             NaN            NaN
# 310696               NaN         NaN       NaN             NaN            NaN
# 310697               NaN         NaN       NaN             NaN            NaN
# 310698               NaN         NaN       NaN             NaN            NaN
# 310699               NaN         NaN     164.8           418.5            NaN
#
#        BrakeSystemName
# 0                Power
# 1                Power
# 2                Power
# 3                Power
# 4                  U/K
# ...                ...
# 310695             NaN
# 310696             NaN
# 310697             NaN
# 310698             NaN
# 310699             NaN
#
# [310700 rows x 23 columns]

# %%
datetext=latest_zip_name.split("_")[-1].split(".")[0]

# %%
df_All.to_csv(fr"{datetext}_Autocare_VCdb_MDHD.csv", index=False)

# %%
df_All.to_excel(fr"{datetext}_Autocare_VCdb_MDHD.xlsx", index=False, engine='openpyxl',sheet_name='Autocare_VCdb')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df_All.to_excel(fr"{datetext}_Autocare_VCdb_MDHD.xlsx", index=False, engine='openpyxl',sheet_name='Autocare_VCdb')
#
# File c:\08_Python_Scripts\.venv\Lib\site-packages\pandas\core\generic.py:2312, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs, autofilter)
#    2298 from pandas.io.formats.excel import ExcelFormatter
#    2300 formatter = ExcelFormatter(
#    2301     df,
#    2302     na_rep=na_rep,
#    (...)   2310     autofilter=autofilter,
#    2311 )
# -> 2312 formatter.write(
#    2313     excel_writer,
#    2314     sheet_name=sheet_name,
#    2315     startrow=startrow,
#    2316     startcol=startcol,
#    2317     freeze_panes=freeze_panes,
#    2318     engine=engine,
#    2319     storage_options=storage_options,
#    2320     engine_kwargs=engine_kwargs,
#    2321 )
#
# File c:\08_Python_Scripts\.venv\Lib\site-packages\pandas\io\formats\excel.py:1023, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#    1020 finally:
#    1021     # make sure to close opened file handles
#    1022     if need_save:
# -> 1023         writer.close()
#
# File c:\08_Python_Scripts\.venv\Lib\site-packages\pandas\io\excel\_base.py:1403, in ExcelWriter.close(self)
#    1401 def close(self) -> None:
#    1402     """synonym for save, to make it more file-like"""
# -> 1403     self._save()
#    1404     self._handles.close()
#
# File c:\08_Python_Scripts\.venv\Lib\site-packages\pandas\io\excel\_openpyxl.py:111, in OpenpyxlWriter._save(self)
#     107 def _save(self) -> None:
#     108     """
#     109     Save workbook to disk.
#     110     """
# --> 111     self.book.save(self._handles.handle)
#     112     if "r+" in self._mode and not isinstance(self._handles.handle, mmap.mmap):
#     113         # truncate file to the written content
#     114         self._handles.handle.truncate()
#
# File c:\08_Python_Scripts\.venv\Lib\site-packages\openpyxl\workbook\workbook.py:386, in Workbook.save(self, filename)
#     384 if self.write_only and not self.worksheets:
#     385     self.create_sheet()
# --> 386 save_workbook(self, filename)
#
# File c:\08_Python_Scripts\.venv\Lib\site-packages\openpyxl\writer\excel.py:294, in save_workbook(workbook, filename)
#     292 workbook.properties.modified = datetime.datetime.now(tz=datetime.timezone.utc).replace(tzinfo=None)
#     293 writer = ExcelWriter(workbook, archive)
# --> 294 writer.save()
#     295 return True
#
# File c:\08_Python_Scripts\.venv\Lib\site-packages\openpyxl\writer\excel.py:275, in ExcelWriter.save(self)
#     273 def save(self):
#     274     """Write data into the archive."""
# --> 275     self.write_data()
#     276     self._archive.close()
#
# File c:\08_Python_Scripts\.venv\Lib\site-packages\openpyxl\writer\excel.py:77, in ExcelWriter.write_data(self)
#      74     custom_override = CustomOverride()
#      75     self.manifest.append(custom_override)
# ---> 77 self._write_worksheets()
#      78 self._write_chartsheets()
#      79 self._write_images()
#
# File c:\08_Python_Scripts\.venv\Lib\site-packages\openpyxl\writer\excel.py:215, in ExcelWriter._write_worksheets(self)
#     212 for idx, ws in enumerate(self.workbook.worksheets, 1):
#     214     ws._id = idx
# --> 215     self.write_worksheet(ws)
#     217     if ws._drawing:
#     218         self._write_drawing(ws._drawing)
#
# File c:\08_Python_Scripts\.venv\Lib\site-packages\openpyxl\writer\excel.py:200, in ExcelWriter.write_worksheet(self, ws)
#     198 else:
#     199     writer = WorksheetWriter(ws)
# --> 200     writer.write()
#     202 ws._rels = writer._rels
#     203 self._archive.write(writer.out, ws.path[1:])
#
# File c:\08_Python_Scripts\.venv\Lib\site-packages\openpyxl\worksheet\_writer.py:359, in WorksheetWriter.write(self)
#     355 """
#     356 High level
#     357 """
#     358 self.write_top()
# --> 359 self.write_rows()
#     360 self.write_tail()
#     361 self.close()
#
# File c:\08_Python_Scripts\.venv\Lib\site-packages\openpyxl\worksheet\_writer.py:125, in WorksheetWriter.write_rows(self)
#     123 with xf.element("sheetData"):
#     124     for row_idx, row in self.rows():
# --> 125         self.write_row(xf, row, row_idx)
#     127 self.xf.send(None)
#
# File c:\08_Python_Scripts\.venv\Lib\site-packages\openpyxl\worksheet\_writer.py:147, in WorksheetWriter.write_row(self, xf, row, row_idx)
#     141 if (
#     142     cell._value is None
#     143     and not cell.has_style
#     144     and not cell._comment
#     145     ):
#     146     continue
# --> 147 write_cell(xf, self.ws, cell, cell.has_style)
#
# File c:\08_Python_Scripts\.venv\Lib\site-packages\openpyxl\cell\_writer.py:86, in etree_write_cell(xf, worksheet, cell, styled)
#      83     if value is not None:
#      84         cell_content.text = safe_string(value)
# ---> 86 xf.write(el)
#
# File c:\08_Python_Scripts\.venv\Lib\site-packages\et_xmlfile\xmlfile.py:120, in _IncrementalFileWriter.write(self, arg)
#     118     default_ns_attr_prefix = None
#     119     uri_to_prefix = {}
# --> 120 incremental_tree._serialize_ns_xml(
#     121     self._file,
#     122     arg,
#     123     nsmap_scope=nsmap_scope,
#     124     global_nsmap=self.global_nsmap,
#     125     short_empty_elements=True,
#     126     is_html=self.is_html,
#     127     is_root=is_root,
#     128     uri_to_prefix=uri_to_prefix,
#     129     default_ns_attr_prefix=default_ns_attr_prefix,
#     130 )
#
# File c:\08_Python_Scripts\.venv\Lib\site-packages\et_xmlfile\incremental_tree.py:626, in _serialize_ns_xml(write, elem, nsmap_scope, global_nsmap, short_empty_elements, is_html, is_root, uri_to_prefix, default_ns_attr_prefix, new_nsmap, **kwargs)
#     607 (
#     608     tag,
#     609     nsmap_scope,
#    (...)    623     new_nsmap=new_nsmap,
#     624 )
#     625 for e in elem:
# --> 626     _serialize_ns_xml(
#     627         write,
#     628         e,
#     629         nsmap_scope,
#     630         global_nsmap,
#     631         short_empty_elements,
#     632         is_html,
#     633         next_remains_root,
#     634         uri_to_prefix,
#     635         default_ns_attr_prefix,
#     636         new_nsmap=None,
#     637     )
#     638 if tag:
#     639     write(f"</{tag}>")
#
# File c:\08_Python_Scripts\.venv\Lib\site-packages\et_xmlfile\incremental_tree.py:626, in _serialize_ns_xml(write, elem, nsmap_scope, global_nsmap, short_empty_elements, is_html, is_root, uri_to_prefix, default_ns_attr_prefix, new_nsmap, **kwargs)
#     607 (
#     608     tag,
#     609     nsmap_scope,
#    (...)    623     new_nsmap=new_nsmap,
#     624 )
#     625 for e in elem:
# --> 626     _serialize_ns_xml(
#     627         write,
#     628         e,
#     629         nsmap_scope,
#     630         global_nsmap,
#     631         short_empty_elements,
#     632         is_html,
#     633         next_remains_root,
#     634         uri_to_prefix,
#     635         default_ns_attr_prefix,
#     636         new_nsmap=None,
#     637     )
#     638 if tag:
#     639     write(f"</{tag}>")
#
# File c:\08_Python_Scripts\.venv\Lib\site-packages\et_xmlfile\incremental_tree.py:639, in _serialize_ns_xml(write, elem, nsmap_scope, global_nsmap, short_empty_elements, is_html, is_root, uri_to_prefix, default_ns_attr_prefix, new_nsmap, **kwargs)
#     626     _serialize_ns_xml(
#     627         write,
#     628         e,
#    (...)    636         new_nsmap=None,
#     637     )
#     638 if tag:
# --> 639     write(f"</{tag}>")
#     640 if elem.tail:
#     641     write(ET._escape_cdata(elem.tail))
#
# KeyboardInterrupt:

# %%
df = df[(df['MakeName'].str.contains("Thor Motor Coach", regex=False, na=False, case=False)) | (df['MakeName'].str.contains("Winnebago", regex=False, na=False, case=False))]
df = df[df['YearID'] > 2019]

df_filtered=df[['YearID','MakeName','ModelName','Liter', 'Cylinders','BlockType','FuelTypeName','BrakeSystemName',"VehicleTypeName"]] #"ClassName",
df_filtered = df_filtered.drop_duplicates()
df_filtered

# %%
df.columns

# %%
df.ModelName.unique()
