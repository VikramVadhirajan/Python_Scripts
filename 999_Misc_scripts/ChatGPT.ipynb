# %%
#!pip install --upgrade openai

# %%
import openai

client = openai.OpenAI(api_key='sk-proj-rSZyk6yQnBbjM74CmvfnT3BlbkFJRqaaRaQTRTjMJHVeE4cU')

# %%
def chat_with_gpt(prompt):  
    response = client.chat.completions.create(  
        model='gpt-3.5-turbo-1106',  
        messages=[{'role': 'system', 'content': "You are a Helpful Assistant"},  
                  {'role': 'user', 'content': prompt}]  
    )  
    return response.choices[0].message.content.strip()

# %%
while True:  
    user_input = input("You: ")  
    if user_input.lower() in ["quit", "exit", "bye"]:  # Fixed condition  
        break  

    response = chat_with_gpt(user_input)  
    print("Chatbot:", response)
# Out:
# Chatbot: DeepSeek is a search engine tool created to help users find information across the deep web, which includes content that is not indexed by traditional search engines. It employs advanced algorithms to crawl and index deep web sites and provides users with access to a wider range of information than what is typically available through standard search engines.
# Chatbot: It seems that "deepseek" is not a known term or concept. Could you please provide more context or clarify what you are referring to?
# Chatbot: Hello! How can I assist you today?
