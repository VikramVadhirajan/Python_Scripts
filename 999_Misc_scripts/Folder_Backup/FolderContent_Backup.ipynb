# %%
import shutil
from pathlib import Path
from tqdm import tqdm
from time import sleep
from IPython.display import clear_output
import os

# %% [markdown]
# ### Targeting list of folders

# %%
Sources=[r"C:\13_Tableau",
r"C:\01_LogicJunior",
r"C:\04_Udemy",
r"C:\05_Simplilearn",
r"C:\06_Freelancing",
r"C:\07_Python_Projects",
r"C:\08_Python_Scripts",
r"C:\09_Power BI files",
r"C:\10_SQL_Files",
r"C:\11_Excel_Files",
r"C:\12_Portfolio_Website",
r"C:\14_Langchain"]

# %%
# paths="C:\12_Portfolio_Website,C:\13_Tableau,C:\01_LogicJunior,C:\04_Udemy,C:\05_Simplilearn,C:\06_Freelancing,C:\07_Python_Projects,C:\08_Python_Scripts,C:\09_Power BI files,C:\10_SQL_Files,C:\11_Excel_Files"
# # paths = input("Enter folder paths separated by comma:\n")
# Sources = [p.strip() for p in paths.split(",")]

# %%
dest= Path(r"C:\99_CopyHDD")

# %% [markdown]
# ### Ignoring List of folders

# %%
ignore_folders = ['.venv', '__pycache__', '.git', 'node_modules',"images_from_videos"]
ignore = shutil.ignore_patterns(ignore_folders)
ignore_keywords=["Frames"]

# %% [markdown]
# ### Ignoring large files such as videos

# %%
ignore_extensions = [".mov"]

# %%
last_folder = None

# %%
def directory_Size(directory):
    totalsize=0
    for root, dirs, files in os.walk(directory):
        for file in files:
            file_path = os.path.join(root, file)
            try:
                size = os.path.getsize(file_path)
                totalsize+=size
            except Exception:
                pass
    for unit in ["B","KB","MB","GB","TB"]:
        if totalsize < 1024:
            return f"{totalsize:.2f} {unit}"
        totalsize /= 1024
    return totalsize

# %%
source=Path(Sources[5])
items = list(source.rglob("*"))
list(items[5].parts)
# Out:
# ['C:\\', '07_Python_Projects', '001_Kidney_Data']

# %%
for source in Sources:
    source=Path(source)
    items = list(source.rglob("*"))
    Parent_Project=str(source).split("\\")[-1]
    for item in tqdm(items, desc=f"Backing up files from {Parent_Project} total of \t \t : {directory_Size(source)}", unit="item", colour='green'):
        # sleep(0.01)
        
        if any(folder in item.parts for folder in ignore_folders):
            continue
        if item.suffix in ignore_extensions:
            continue    
        if any(keyword in part for part in item.parts for keyword in ignore_keywords):
            continue
        relative_path = item.relative_to(source)
        first_folder = relative_path.parts[0]

        target = dest/Parent_Project / item.relative_to(source)


        if item.is_dir():
            target.mkdir(parents=True, exist_ok=True)

        else:
            target.parent.mkdir(parents=True, exist_ok=True)
            shutil.copy2(item, target)
            # print("Copied:", item)
            # sleep(0.05)
            # clear_output(wait=True)
                
print(f"Backup completed successfully! copied \t \t :{directory_Size(dest)} of Data")
# Out:
# Backing up files from 13_Tableau total of 	 	 : 230.01 KB: 100%|██████████| 14/14 [00:00<00:00, 1170.50item/s]
# Backing up files from 01_LogicJunior total of 	 	 : 69.67 MB: 100%|██████████| 9/9 [00:00<00:00, 28.99item/s]
# Backing up files from 04_Udemy total of 	 	 : 88.75 MB: 100%|██████████| 126/126 [00:00<00:00, 307.42item/s]
# Backing up files from 05_Simplilearn total of 	 	 : 367.97 MB: 100%|██████████| 306/306 [00:01<00:00, 263.89item/s]
# Backing up files from 06_Freelancing total of 	 	 : 23.90 MB: 100%|██████████| 23/23 [00:00<00:00, 192.16item/s]
# Backing up files from 07_Python_Projects total of 	 	 : 4.73 GB: 100%|██████████| 81834/81834 [00:00<00:00, 134523.43item/s]
# Backing up files from 08_Python_Scripts total of 	 	 : 2.05 GB: 100%|██████████| 61896/61896 [00:00<00:00, 375905.72item/s]
# Backing up files from 09_Power BI files total of 	 	 : 45.60 MB: 100%|██████████| 153/153 [00:00<00:00, 1711.73item/s]
# Backing up files from 10_SQL_Files total of 	 	 : 349.19 KB: 100%|██████████| 138/138 [00:00<00:00, 7467.51item/s]
# Backing up files from 11_Excel_Files total of 	 	 : 1.02 KB: 100%|██████████| 4/4 [00:00<00:00, 2007.32item/s]
# Backing up files from 12_Portfolio_Website total of 	 	 : 21.66 MB: 100%|██████████| 435/435 [00:00<00:00, 6593.48item/s]
# Backing up files from 14_Langchain total of 	 	 : 1.94 GB: 100%|██████████| 72284/72284 [00:00<00:00, 434963.17item/s]
# Backup completed successfully! copied 	 	 :810.21 MB of Data

# %% [markdown]
# ### Copy specific Items from the folder

# %%
destination=Path(r"C:\99_CopyHDD\Ipynb_files")

# %%
neededfileextension=".ipynb"

# %%
for source in Sources:
    source=Path(source)
    items = list(source.rglob("*"))
    Parent_Project=str(source).split("\\")[-1]
    for item in tqdm(items, desc=f"Backing up files from {Parent_Project} total of \t \t : {directory_Size(source)}", unit="item", colour='green'):
        # sleep(0.01)
        
        if any(folder in item.parts for folder in ignore_folders):
            continue
        if item.suffix == neededfileextension:
            relative_path = item.relative_to(source)
            first_folder = relative_path.parts[0]

            target = destination/Parent_Project/ item.relative_to(source)


            if item.is_dir():
                target.mkdir(parents=True, exist_ok=True)

            else:
                target.parent.mkdir(parents=True, exist_ok=True)
                shutil.copy2(item, target)
                # print("Copied:", item)
                # sleep(0.05)
                # clear_output(wait=True)
            
print(f"Backup completed successfully! copied \t \t :{directory_Size(dest)} of Data")
# Out:
# Backing up files from 13_Tableau total of 	 	 : 230.01 KB: 100%|██████████| 14/14 [00:00<?, ?item/s]
# Backing up files from 01_LogicJunior total of 	 	 : 54.33 MB: 100%|██████████| 8/8 [00:00<?, ?item/s]
# Backing up files from 04_Udemy total of 	 	 : 66.19 MB: 100%|██████████| 86/86 [00:00<00:00, 3688.13item/s]
# Backing up files from 05_Simplilearn total of 	 	 : 367.97 MB: 100%|██████████| 306/306 [00:00<00:00, 2427.10item/s]
# Backing up files from 06_Freelancing total of 	 	 : 23.88 MB: 100%|██████████| 21/21 [00:00<00:00, 10530.89item/s]
# Backing up files from 07_Python_Projects total of 	 	 : 3.01 GB: 100%|██████████| 79418/79418 [00:00<00:00, 203668.96item/s]
# Backing up files from 08_Python_Scripts total of 	 	 : 2.04 GB: 100%|██████████| 61255/61255 [00:00<00:00, 218765.27item/s]
# Backing up files from 09_Power BI files total of 	 	 : 45.60 MB: 100%|██████████| 153/153 [00:00<?, ?item/s]
# Backing up files from 10_SQL_Files total of 	 	 : 349.19 KB: 100%|██████████| 138/138 [00:00<00:00, 21447.88item/s]
# Backing up files from 11_Excel_Files total of 	 	 : 1.02 KB: 100%|██████████| 4/4 [00:00<?, ?item/s]
# Backing up files from 12_Portfolio_Website total of 	 	 : 21.66 MB: 100%|██████████| 435/435 [00:00<00:00, 436593.02item/s]
# Backup completed successfully! copied 	 	 :75.03 MB of Data
