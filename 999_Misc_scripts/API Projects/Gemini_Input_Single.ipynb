# %%
# %pip install pytext
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pytext (from versions: none)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for pytext

# %%
import pandas as pd
import google.generativeai as genai
import os
from time import sleep
from tqdm import tqdm
from IPython.display import clear_output
import os
from dotenv import load_dotenv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 import google.generativeai as genai
#       3 import os
#       4 from time import sleep
#
# ModuleNotFoundError: No module named 'google'

# %%
load_dotenv("keys.env")
APIKEY=os.environ.get("geminiapikey")

# %%
genai.configure(api_key=APIKEY)
gencon={"temperature":0.9,"top_p":1, "top_k":1, "max_output_tokens":2048 }

model = genai.GenerativeModel('gemini-pro',generation_config=gencon)

# %%
question=input("enter your question")
response = model.generate_content(question)
print(response.text)
