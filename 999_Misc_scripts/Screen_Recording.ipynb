# %%
# %pip install -U pyscreenrec
# Out:
# ...
#   Using cached pyscreenrec-0.6-py3-none-any.whl (582 kB)
# ...
#   Using cached numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
# ...
#   Using cached opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
# ...
#   Using cached mss-9.0.2-py3-none-any.whl (23 kB)
# ...
#   Using cached opencv_python-4.13.0.90-cp37-abi3-win_amd64.whl (40.2 MB)
#   Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
#   Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pyscreenrec
import time

# Create a ScreenRecorder instance
recorder = pyscreenrec.ScreenRecorder()

# %%
time.sleep(3)
# Start recording (output file, FPS, optional monitor settings)
# The start_recording method runs in a background thread
recorder.start_recording("my_recording.mp4", 30) 

print("Recording started for 10 seconds...")
# Record for a specific duration
time.sleep(10) 

# Stop recording and save the file
recorder.stop_recording()

print("Recording saved to my_recording.mp4")
# Out:
# Recording started for 10 seconds...
# Recording saved to my_recording.mp4
