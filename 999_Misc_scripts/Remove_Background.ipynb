# %%
# %pip install rembg -q
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\Users\\vikram.vadhirajan\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\cv2\\cv2.pyd'
# Consider using the `--user` option or check the permissions.
#
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from rembg import remove
from PIL import Image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from rembg import remove
#       2 from PIL import Image
#
# ModuleNotFoundError: No module named 'rembg'

# %%
from IPython.display import Image as IPImage

# %%
IPImage(filename=r"C:\Users\vikram.vadhirajan\OneDrive - Trico\Vikram Data research\NEW Cargo Organizer\ProductImages\B0C4PJSVF4.jpg")
